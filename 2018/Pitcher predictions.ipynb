# %% [markdown]
# # Evaluating different projections of MLB pitching statistics for 2018 season
# ##### The purpose of this project was to evaluate how well different models predicted a player's statistics for the 2018 MLB season. There are 6 different models evaluated in this project- ATC, Depth Charts, Fangraphs, Steamer, The Bat, ZiPS, and an average of those 5 projections. Raw data of each projection was downloaded via fangraphs.com and compressed into one standardized spreadsheet. Exact number of projections may vary from player to player as some projections excluded certain players from their projections.
# ##### This project is not fully complete as the 2018 MLB season has not yet completed. Currently, this workbook does some data cleansing, then data manipulation to calculate average projections before adding the average projection for each player to the table of projections. Upon completion of the 2018 MLB season, this workbook will be updated with each player's actual statistics from the season, along with some work and visualization to see how well each projection model did at predicting players' stats.

# %%
import pandas as pd
pd.set_option('display.max_columns', 50)
pd.set_option('display.max_rows', 25)

# %%
projections = pd.read_csv("2018-MLB-Projections-Pitchers.csv")

# %%
projections.head(10)
# Out:
#              Name    Team Type  W  L   SV  HLD   ERA  GS   G    IP   H  ER  \
# 0  Williams Jerez  Angels  ATC  0  0  0.0  NaN  4.64   0   5   6.0   6   3
# 1     Jason Gurka  Angels  ATC  1  0  0.0  NaN  4.33   0  18  11.0  15   5
# 2      Ty Buttrey  Angels  ATC  1  1  0.0  NaN  4.92   0  11  12.0  12   6
# 3       John Lamb  Angels  ATC  1  1  0.0  NaN  5.72   1   3  14.0  17   9
# 4    Akeel Morris  Angels  ATC  0  1  0.0  NaN  4.25   0  16  16.0  15   8
# 5      Dayan Diaz  Angels  ATC  1  1  0.0  NaN  4.72   0  14  16.0  16   9
# 6  Miguel Almonte  Angels  ATC  0  0  0.0  NaN  4.84   1  11  18.0  19  10
# 7    Deck McGuire  Angels  ATC  1  1  0.0  NaN  4.65   1   8  20.0  20  10
# 8     Taylor Cole  Angels  ATC  0  1  0.0  NaN  7.36   1  18  21.0  30  17
# 9     Noe Ramirez  Angels  ATC  1  1  0.0  NaN  3.95   0  25  27.0  23  12
#
#    HR  SO  BB  WHIP    K/9  BB/9   FIP  WAR    ADP  playerid
# 0   1   5   3  1.52   7.21  4.52  4.53  NaN  999.0     14338
# 1   1  10   5  1.77   8.02  3.89  3.47  NaN  999.0      8007
# 2   2   9   6  1.57   7.23  4.96  4.96  NaN  999.0     14719
# 3   2  10   5  1.58   6.20  3.29  5.17  NaN  999.0      8493
# 4   3  18   9  1.47  10.01  5.06  5.22  NaN  999.0     12185
# 5   3  15   7  1.42   8.52  3.75  4.71  NaN  999.0     11543
# 6   2  16   8  1.52   8.22  4.15  4.31  NaN  999.0     14139
# 7   2  16   8  1.41   7.29  3.54  4.51  NaN  999.0     11596
# 8   1  16   8  1.83   6.88  3.27  3.84  NaN  999.0     11964
# 9   5  28  11  1.27   9.37  3.67  4.72  NaN  999.0     12800

# %%
projections.columns
# Out:
# Index(['Name', 'Team', 'Type', 'W', 'L', 'SV', 'HLD', 'ERA', 'GS', 'G', 'IP',
#        'H', 'ER', 'HR', 'SO', 'BB', 'WHIP', 'K/9', 'BB/9', 'FIP', 'WAR', 'ADP',
#        'playerid'],
#       dtype='object')

# %% [markdown]
# ### Find columns with NaNs and remove

# %%
nas = projections.columns[projections.isna().any()].tolist()
nas
# Out:
# ['SV', 'HLD', 'WAR']

# %%
projections = projections.drop(nas, axis=1)

# %%
projections.columns[projections.isna().any()].tolist()
# Out:
# []

# %%
projections.head()
# Out:
#              Name    Team Type  W  L   ERA  GS   G    IP   H  ER  HR  SO  BB  \
# 0  Williams Jerez  Angels  ATC  0  0  4.64   0   5   6.0   6   3   1   5   3
# 1     Jason Gurka  Angels  ATC  1  0  4.33   0  18  11.0  15   5   1  10   5
# 2      Ty Buttrey  Angels  ATC  1  1  4.92   0  11  12.0  12   6   2   9   6
# 3       John Lamb  Angels  ATC  1  1  5.72   1   3  14.0  17   9   2  10   5
# 4    Akeel Morris  Angels  ATC  0  1  4.25   0  16  16.0  15   8   3  18   9
#
#    WHIP    K/9  BB/9   FIP    ADP  playerid
# 0  1.52   7.21  4.52  4.53  999.0     14338
# 1  1.77   8.02  3.89  3.47  999.0      8007
# 2  1.57   7.23  4.96  4.96  999.0     14719
# 3  1.58   6.20  3.29  5.17  999.0      8493
# 4  1.47  10.01  5.06  5.22  999.0     12185

# %%
projections.columns
# Out:
# Index(['Name', 'Team', 'Type', 'W', 'L', 'ERA', 'GS', 'G', 'IP', 'H', 'ER',
#        'HR', 'SO', 'BB', 'WHIP', 'K/9', 'BB/9', 'FIP', 'ADP', 'playerid'],
#       dtype='object')

# %% [markdown]
# ### Create list of all player names that have projections, plus dictionary storing the number of different projections for each name
# ##### To make the average projections more worthwhile, I will only use players that had at least 3 projections

# %%
names = []
nameCounter = {}
for index, row in projections.iterrows():
    name = row["Name"]
    if name not in names:
        names.append(name)
        nameCounter[name] = 1
    else:
        nameCounter[name] += 1
print(len(names))
# Out:
# 996

# %%
nameCounter
# Out:
# {'Williams Jerez': 4,
#  'Jason Gurka': 3,
#  'Ty Buttrey': 5,
#  'John Lamb': 3,
#  'Akeel Morris': 5,
#  'Dayan Diaz': 5,
#  'Miguel Almonte': 5,
#  'Deck McGuire': 3,
#  'Taylor Cole': 3,
#  'Noe Ramirez': 5,
#  'Eduardo Paredes': 4,
#  'Felix Pena': 5,
#  'Luke Farrell': 5,
#  'Jose Alvarez': 5,
#  'Odrisamer Despaigne': 5,
#  'Junichi Tazawa': 5,
#  'Cam Bedrosian': 5,
#  'Hansel Robles': 5,
#  'Keynan Middleton': 4,
#  'Blake Wood': 5,
#  'Jim Johnson': 5,
#  'Blake Parker': 5,
#  'Nick Tropeano': 5,
#  'Andrew Heaney': 5,
#  'Parker Bridwell': 5,
#  'JC Ramirez': 5,
#  'Tyler Skaggs': 5,
#  'Matt Shoemaker': 5,
#  'Garrett Richards': 6,
#  'Shohei Ohtani': 6,
#  'Jandel Gustave': 4,
#  'Brady Rodgers': 5,
#  'Reymin Guduan': 5,
#  'Tony Sipp': 5,
#  'Francis Martes': 5,
#  'Joe Smith': 5,
#  'Will Harris': 5,
#  'Ryan Pressly': 5,
#  'Hector Rondon': 5,
#  'Roberto Osuna': 6,
#  'Chris Devenski': 6,
#  'Brad Peacock': 6,
#  'Collin McHugh': 5,
#  'Lance McCullers Jr.': 6,
#  'Charlie Morton': 6,
#  'Dallas Keuchel': 6,
#  'Gerrit Cole': 6,
#  'Justin Verlander': 6,
#  'Dean Kiekhefer': 3,
#  'Eric Jokisch': 3,
#  'Josh Lucas': 3,
#  'Raul Alcantara': 4,
#  'Carlos Ramirez': 4,
#  'Shawn Kelley': 5,
#  'Ryan Dull': 5,
#  'Frankie Montas': 5,
#  'Edwin Jackson': 5,
#  'Daniel Coulombe': 5,
#  'Chris Bassitt': 5,
#  'Cory Gearrin': 5,
#  'Ryan Buchter': 5,
#  'Chris Hatcher': 5,
#  'Fernando Rodney': 6,
#  'Liam Hendriks': 5,
#  'Jeurys Familia': 5,
#  'Emilio Pagan': 4,
#  'Blake Treinen': 5,
#  'Yusmeiro Petit': 5,
#  'Brett Anderson': 5,
#  'Paul Blackburn': 5,
#  'Trevor Cahill': 5,
#  'Daniel Gossett': 5,
#  'Andrew Triggs': 5,
#  'Daniel Mengden': 5,
#  'Mike Fiers': 5,
#  'Kendall Graveman': 5,
#  'Sean Manaea': 6,
#  'Thomas Pannone': 4,
#  'Rhiner Cruz': 3,
#  'Luis Santos': 3,
#  'Sam Moll': 4,
#  'Jake Petricka': 5,
#  'Taylor Guerrieri': 5,
#  'Tim Mayza': 4,
#  'Craig Breslow': 3,
#  'Matt Dermody': 3,
#  'Ryan Borucki': 4,
#  'Tyler Clippard': 5,
#  'David Paulino': 5,
#  'Sam Gaviglio': 5,
#  'Danny Barnes': 6,
#  'Ken Giles': 6,
#  'Ryan Tepera': 6,
#  'Mark Leiter': 5,
#  'Joe Biagini': 6,
#  'Aaron Sanchez': 6,
#  'Marco Estrada': 6,
#  'Marcus Stroman': 6,
#  'Jacob Lindgren': 3,
#  'Shane Carle': 5,
#  'Jason Hursh': 5,
#  'Jesse Biddle': 5,
#  'Josh Ravin': 3,
#  'Rex Brothers': 5,
#  'Luke Jackson': 3,
#  'Dan Winkler': 4,
#  'Chase Whitley': 5,
#  'Max Fried': 5,
#  'Peter Moylan': 5,
#  'Sam Freeman': 5,
#  'A.J. Minter': 5,
#  "Darren O'Day": 5,
#  'Chad Bell': 5,
#  'Arodys Vizcaino': 6,
#  'Jose Ramirez': 5,
#  'Brad Brach': 5,
#  'Anibal Sanchez': 5,
#  'Brandon McCarthy': 5,
#  'Luiz Gohara': 6,
#  'Sean Newcomb': 6,
#  'Mike Foltynewicz': 6,
#  'Kevin Gausman': 6,
#  'Julio Teheran': 6,
#  'Adrian Houser': 5,
#  'Jimmy Nelson': 5,
#  'Jim Henderson': 3,
#  'Paolo Espino': 3,
#  'Taylor Williams': 4,
#  'Xavier Cedeno': 4,
#  'Michael Brady': 3,
#  'Alec Asher': 5,
#  'Aaron Wilkerson': 5,
#  'Ariel Hernandez': 4,
#  'Jordan Lyles': 5,
#  'Matt Albers': 5,
#  'Jeremy Jeffress': 5,
#  'Dan Jennings': 5,
#  'Joakim Soria': 5,
#  'Jacob Barnes': 5,
#  'Corey Knebel': 5,
#  'Junior Guerra': 5,
#  'Josh Hader': 5,
#  'Jake Thompson': 5,
#  'Wade Miley': 5,
#  'Brent Suter': 5,
#  'Brandon Woodruff': 5,
#  'Jhoulys Chacin': 5,
#  'Chase Anderson': 5,
#  'Zach Davies': 5,
#  'Gio Gonzalez': 6,
#  'Austin Gomber': 5,
#  'Mike Mayers': 5,
#  'Tyler Webb': 5,
#  'Giovanny Gallegos': 4,
#  'John Gant': 5,
#  'Chasen Shreve': 5,
#  'John Brebbia': 5,
#  'Brett Cecil': 5,
#  'Bud Norris': 5,
#  'Matt Bowman': 5,
#  'Tyler Lyons': 5,
#  'Luke Gregerson': 5,
#  'Dominic Leone': 5,
#  'Alex Reyes': 5,
#  'Jack Flaherty': 5,
#  'Adam Wainwright': 6,
#  'Tyson Ross': 5,
#  'Miles Mikolas': 5,
#  'Luke Weaver': 6,
#  'Michael Wacha': 6,
#  'Carlos Martinez': 6,
#  'Duane Underwood Jr.': 5,
#  'Drew Smyly': 4,
#  'Randy Rosario': 4,
#  'Cory Mazzoni': 5,
#  'Alec Mills': 4,
#  'Kyle Ryan': 3,
#  'Dillon Maples': 5,
#  'Rob Zastryzny': 5,
#  'Jen-Ho Tseng': 5,
#  'Brian Duensing': 5,
#  'Justin Wilson': 5,
#  'Jorge De La Rosa': 5,
#  'Brandon Morrow': 6,
#  'Steve Cishek': 5,
#  'Pedro Strop': 5,
#  'Jesse Chavez': 5,
#  'Brandon Kintzler': 5,
#  'Carl Edwards Jr.': 5,
#  'Mike Montgomery': 5,
#  'Jaime Garcia': 6,
#  'Tyler Chatwood': 5,
#  'Kyle Hendricks': 6,
#  'Yu Darvish': 6,
#  'Cole Hamels': 5,
#  'Jon Lester': 6,
#  'Jose Quintana': 6,
#  'Rubby de la Rosa': 3,
#  'Henry Owens': 4,
#  'Brad Goldberg': 3,
#  'Neftali Feliz': 5,
#  'Matt Koch': 5,
#  'Enrique Burgos': 3,
#  'Clay Buchholz': 5,
#  'Stefan Crichton': 4,
#  'Troy Scribner': 5,
#  'Silvino Bracho': 5,
#  'Jake Barrett': 5,
#  'Albert Suarez': 3,
#  'T.J. McFarland': 5,
#  'Braden Shipley': 5,
#  'Andrew Chafin': 5,
#  'Jimmie Sherfy': 5,
#  'Shelby Miller': 5,
#  'Jake Diekman': 5,
#  'Yoshihisa Hirano': 3,
#  'Brad Boxberger': 5,
#  'Brad Ziegler': 5,
#  'Randall Delgado': 5,
#  'Archie Bradley': 6,
#  'Matt Andriese': 5,
#  'Taijuan Walker': 6,
#  'Zack Godley': 6,
#  'Patrick Corbin': 5,
#  'Robbie Ray': 6,
#  'Zack Greinke': 6,
#  'J.T. Chargois': 4,
#  'Zach Neal': 3,
#  'Pat Venditte': 3,
#  'Tyler Pill': 3,
#  'Zac Rosscup': 6,
#  'Edward Paredes': 5,
#  'Erik Goeddel': 5,
#  'Yimi Garcia': 5,
#  'Julio Urias': 5,
#  'John Axford': 5,
#  'Tom Koehler': 5,
#  'Walker Buehler': 5,
#  'Tony Cingrani': 5,
#  'Josh Fields': 5,
#  'Zach McAllister': 5,
#  'Daniel Hudson': 3,
#  'Ryan Madson': 5,
#  'Pedro Baez': 5,
#  'Scott Alexander': 5,
#  'Kenley Jansen': 6,
#  'Ross Stripling': 5,
#  'Brock Stewart': 5,
#  'Hyun-Jin Ryu': 5,
#  'Rich Hill': 6,
#  'Kenta Maeda': 6,
#  'Alex Wood': 6,
#  'Clayton Kershaw': 6,
#  'Reyes Moronta': 4,
#  'Roberto Gomez': 4,
#  'Jose Valdez': 2,
#  'Will Smith': 5,
#  'Steven Okert': 5,
#  'Josh Osich': 5,
#  'Tyler Beede': 5,
#  'Derek Law': 5,
#  'Derek Holland': 5,
#  'Hunter Strickland': 5,
#  'Sam Dyson': 5,
#  'Tony Watson': 5,
#  'Mark Melancon': 6,
#  'Madison Bumgarner': 6,
#  'Chris Stratton': 5,
#  'Ty Blach': 5,
#  'Johnny Cueto': 6,
#  'Jeff Samardzija': 6,
#  'Myles Jaye': 3,
#  'Adam Wilk': 3,
#  'Adam Plutko': 5,
#  'Ben Taylor': 4,
#  'Neil Ramirez': 3,
#  'Shawn Morimando': 5,
#  'Cody Anderson': 5,
#  'Oliver Perez': 3,
#  'Tyler Olson': 5,
#  'James Hoyt': 5,
#  'Ryan Merritt': 5,
#  'Dan Otero': 5,
#  'Nick Goody': 5,
#  'Cody Allen': 5,
#  'Andrew Miller': 5,
#  'Brad Hand': 5,
#  'Danny Salazar': 5,
#  'Josh Tomlin': 5,
#  'Mike Clevinger': 6,
#  'Trevor Bauer': 6,
#  'Carlos Carrasco': 6,
#  'Corey Kluber': 6,
#  'Ryan Garton': 3,
#  'Dario Alvarez': 5,
#  'Max Povse': 4,
#  'Shawn Armstrong': 3,
#  'Nick Rumbelow': 4,
#  'Mike Morin': 3,
#  'Rob Whalen': 5,
#  'Chasen Bradford': 5,
#  'Casey Lawrence': 5,
#  'Marc Rzepczynski': 6,
#  'Roenis Elias': 5,
#  'Sam Tuivailala': 5,
#  'Christian Bergman': 3,
#  'Dan Altavilla': 4,
#  'Zach Duke': 5,
#  'Justin Grimm': 5,
#  'Wade LeBlanc': 5,
#  'James Pazos': 6,
#  'Nick Vincent': 6,
#  'Adam Warren': 5,
#  'Edwin Diaz': 6,
#  'Hisashi Iwakuma': 5,
#  'Alex Colome': 5,
#  'David Phelps': 4,
#  'Juan Nicasio': 6,
#  'Marco Gonzales': 6,
#  'Felix Hernandez': 6,
#  'James Paxton': 6,
#  'Mike Leake': 6,
#  'Drew Rucinski': 3,
#  'Tyler Cloyd': 3,
#  'Colton Murray': 3,
#  'Tayron Guerrero': 4,
#  'Javy Guerra': 3,
#  'Jumbo Diaz': 3,
#  'Nick Wittgren': 5,
#  'Caleb Smith': 5,
#  'Drew Steckenrider': 5,
#  "Chris O'Grady": 5,
#  'Kyle Barraclough': 5,
#  'Dillon Peters': 5,
#  'Wei-Yin Chen': 5,
#  'Sandy Alcantara': 5,
#  'Jarlin Garcia': 4,
#  'Adam Conley': 5,
#  'Jose Urena': 5,
#  'Dan Straily': 5,
#  'Cody Martin': 3,
#  'Gerson Bautista': 4,
#  'Kevin McGowan': 3,
#  'Jacob Rhame': 5,
#  'Jamie Callahan': 4,
#  'Matt Purke': 3,
#  'Tyler Bashlor': 4,
#  'Chris Flexen': 5,
#  'Buddy Baumann': 5,
#  'Chris Beck': 3,
#  'Paul Sewald': 5,
#  'Jerry Blevins': 5,
#  'AJ Ramos': 5,
#  'Anthony Swarzak': 5,
#  'Rafael Montero': 3,
#  'Robert Gsellman': 5,
#  'Seth Lugo': 5,
#  'Zack Wheeler': 5,
#  'Steven Matz': 5,
#  'Jason Vargas': 5,
#  'Noah Syndergaard': 6,
#  'Jacob deGrom': 6,
#  'Wander Suero': 5,
#  'Trevor Gott': 5,
#  'Joe Ross': 5,
#  'Josh Edgin': 3,
#  'Tommy Milone': 3,
#  'Austin Voth': 5,
#  'Sammy Solis': 5,
#  'Koda Glover': 5,
#  'Matt Grace': 5,
#  'Carlos Torres': 3,
#  'Joaquin Benoit': 5,
#  'Greg Holland': 4,
#  'Erick Fedde': 4,
#  'Sean Doolittle': 5,
#  'Kelvin Herrera': 6,
#  'Jeremy Hellickson': 5,
#  'Stephen Strasburg': 6,
#  'Tanner Roark': 6,
#  'Max Scherzer': 6,
#  'Jeff Ferrell': 3,
#  'Tim Melville': 3,
#  'Sean Gilmartin': 3,
#  'Andrew Faulkner': 3,
#  'Jimmy Yacabonis': 4,
#  'Jhan Marinez': 3,
#  'Mike Wright': 5,
#  'Tanner Scott': 4,
#  'Donnie Hart': 4,
#  'Richard Bleier': 5,
#  'Miguel Castro': 5,
#  'Mychal Givens': 5,
#  'Gabriel Ynoa': 5,
#  'Andrew Cashner': 5,
#  'Alex Cobb': 5,
#  'Dylan Bundy': 5,
#  'Jonathan Aro': 5,
#  'Rowan Wick': 3,
#  'Dillon Overton': 3,
#  'Walker Lockett': 4,
#  'Kyle McGrath': 4,
#  'Colten Brewer': 4,
#  'Jose Torres': 4,
#  'Miguel Diaz': 4,
#  'Carter Capps': 3,
#  'Kazuhisa Makita': 3,
#  'Phil Maton': 4,
#  'Colin Rea': 5,
#  'Kirby Yates': 5,
#  'Robbie Erlin': 5,
#  'Craig Stammen': 5,
#  'Matt Strahm': 5,
#  'Christian Friedrich': 3,
#  'Bryan Mitchell': 5,
#  'Dinelson Lamet': 6,
#  'Luis Perdomo': 5,
#  'Clayton Richard': 5,
#  'Pedro Beato': 3,
#  'Yacksel Rios': 4,
#  'Victor Arano': 4,
#  'Henderson Alvarez': 3,
#  'Aaron Loup': 5,
#  'Luis Avilan': 5,
#  'Edubray Ramos': 5,
#  'Pat Neshek': 5,
#  'Tommy Hunter': 5,
#  'Adam Morgan': 5,
#  'Zach Eflin': 5,
#  'Hector Neris': 5,
#  'Vince Velasquez': 5,
#  'Nick Pivetta': 6,
#  'Jerad Eickhoff': 6,
#  'Jake Arrieta': 6,
#  'Aaron Nola': 6,
#  'Nick Burdi': 4,
#  'Casey Sadler': 3,
#  'Damien Magnifico': 3,
#  'Edgar Santana': 4,
#  'Clay Holmes': 5,
#  'Nik Turley': 5,
#  'Nick Kingham': 5,
#  'Buddy Boshers': 5,
#  'Dovydas Neverauskas': 4,
#  'Kevin Siegrist': 3,
#  'Keone Kela': 5,
#  'Kyle Crick': 5,
#  'Michael Feliz': 6,
#  'A.J. Schugel': 5,
#  'Felipe Vazquez': 6,
#  'Steven Brault': 5,
#  'Trevor Williams': 5,
#  'Joe Musgrove': 6,
#  'Chad Kuhl': 5,
#  'Ivan Nova': 5,
#  'Jameson Taillon': 6,
#  'Chris Archer': 6,
#  'Chi Chi Gonzalez': 3,
#  'R.J. Alvarez': 3,
#  'Jon Niese': 2,
#  'Shawn Tolleson': 3,
#  'Zac Curtis': 4,
#  'Nick Gardewine': 4,
#  'Ronald Herrera': 5,
#  'Connor Sadzeck': 5,
#  'Chris Rowley': 3,
#  'Deolis Guerra': 3,
#  'Drew Hutchison': 4,
#  'Eddie Butler': 5,
#  'Yohander Mendez': 5,
#  'Chris Martin': 5,
#  'Austin Bibens-Dirkx': 3,
#  'Jose Leclerc': 5,
#  'Tony Barnette': 5,
#  'Matt Bush': 5,
#  'Alex Claudio': 5,
#  'Bartolo Colon': 6,
#  'Yovani Gallardo': 3,
#  'Mike Minor': 5,
#  'Chris Tillman': 5,
#  'Doug Fister': 5,
#  'Martin Perez': 5,
#  'Matt Moore': 5,
#  'Diego Castillo': 4,
#  'Ryan Weber': 3,
#  'Dan Runzler': 3,
#  'Hunter Wood': 5,
#  'Mike Broadway': 3,
#  'Vidal Nuno': 3,
#  'Chih-Wei Hu': 5,
#  'Jaime Schultz': 5,
#  'Chaz Roe': 5,
#  'Ryan Yarbrough': 5,
#  'Hoby Milner': 5,
#  'Ryne Stanek': 5,
#  'Andrew Kittredge': 5,
#  'Jose Alvarado': 4,
#  'Wilmer Font': 5,
#  'Anthony Banda': 5,
#  'Austin Pruitt': 5,
#  'Sergio Romo': 5,
#  'Dustin McGowan': 3,
#  'Andrew Moore': 5,
#  'Yonny Chirinos': 5,
#  'Tyler Glasnow': 5,
#  'Blake Snell': 6,
#  'Jake Faria': 5,
#  'Hector Velazquez': 5,
#  'Austin Maddox': 4,
#  'Josh Smith': 3,
#  'Robby Scott': 5,
#  'Tyler Thornburg': 5,
#  'Brian Johnson': 5,
#  'Brandon Workman': 5,
#  'Carson Smith': 5,
#  'Heath Hembree': 5,
#  'Joe Kelly': 5,
#  'Matt Barnes': 5,
#  'Craig Kimbrel': 6,
#  'Steven Wright': 5,
#  'Eduardo Rodriguez': 6,
#  'Nathan Eovaldi': 5,
#  'Drew Pomeranz': 6,
#  'David Price': 6,
#  'Rick Porcello': 6,
#  'Chris Sale': 6,
#  'Kyle Crockett': 3,
#  'Keury Mella': 4,
#  'Joe Mantiply': 3,
#  'Daniel Wright': 5,
#  'Kevin Quackenbush': 5,
#  'Rookie Davis': 5,
#  'Jackson Stephens': 5,
#  'Matt Wisler': 5,
#  'Austin Brice': 5,
#  'Cody Reed': 5,
#  'Justin Nicolino': 5,
#  'Jared Hughes': 5,
#  'Wandy Peralta': 5,
#  'David Hernandez': 5,
#  'Michael Lorenzen': 6,
#  'Raisel Iglesias': 6,
#  'Amir Garrett': 5,
#  'Lucas Sims': 5,
#  'Tyler Mahle': 6,
#  'Brandon Finnegan': 5,
#  'Sal Romano': 6,
#  'Robert Stephenson': 6,
#  'Anthony DeSclafani': 5,
#  'Matt Harvey': 5,
#  'Homer Bailey': 6,
#  'Luis Castillo': 6,
#  'Brett Oberholtzer': 2,
#  'Jairo Diaz': 5,
#  'Brooks Pounders': 3,
#  'Yency Almonte': 4,
#  'Carlos Estevez': 5,
#  'Mike Dunn': 5,
#  'Scott Oberg': 5,
#  'Adam Ottavino': 5,
#  'Santiago Casilla': 5,
#  'David Holmberg': 4,
#  'Jake McGee': 6,
#  'Wade Davis': 6,
#  'Seung Hwan Oh': 6,
#  'Bryan Shaw': 6,
#  'Chris Rusin': 6,
#  'Jeff Hoffman': 6,
#  'Antonio Senzatela': 6,
#  'Tyler Anderson': 6,
#  'Kyle Freeland': 5,
#  'Chad Bettis': 5,
#  'German Marquez': 6,
#  'Jon Gray': 6,
#  'Andres Machado': 4,
#  'Eric Skoglund': 5,
#  'Scott Barlow': 5,
#  'Brian Flynn': 5,
#  'Jorge Lopez': 5,
#  'Trevor Oaks': 5,
#  'Burch Smith': 5,
#  'Kevin McCarthy': 5,
#  'Wily Peralta': 5,
#  'Jesse Hahn': 4,
#  'Brandon Maurer': 5,
#  'Ben Lively': 5,
#  'Nathan Karns': 5,
#  'Jakob Junis': 6,
#  'Ian Kennedy': 5,
#  'Danny Duffy': 6,
#  'Jason Hammel': 5,
#  'Sandy Baez': 4,
#  'Hunter Cervenka': 3,
#  'Victor Alcantara': 3,
#  'Ryan Carpenter': 5,
#  'Artie Lewicki': 5,
#  'Johnny Barbato': 5,
#  'Zac Reininger': 4,
#  'Blaine Hardy': 5,
#  'Joe Jimenez': 4,
#  'Drew VerHagen': 5,
#  'Daniel Stumpf': 5,
#  'Warwick Saupold': 5,
#  'Jacob Turner': 5,
#  'Alex Wilson': 5,
#  'Shane Greene': 5,
#  'Buck Farmer': 5,
#  'Francisco Liriano': 5,
#  'Daniel Norris': 5,
#  'Matthew Boyd': 5,
#  'Jordan Zimmermann': 5,
#  'Michael Fulmer': 5,
#  'John Curtiss': 4,
#  'Felix Jorge': 5,
#  'Gabriel Moya': 4,
#  'Michael Pineda': 3,
#  'Chase De Jong': 4,
#  'Dietrich Enns': 5,
#  'Austin Adams': 7,
#  'Fernando Romero': 4,
#  'Trevor May': 5,
#  'Stephen Gonsalves': 5,
#  'Alan Busenitz': 5,
#  'Luke Bard': 4,
#  'Oliver Drake': 5,
#  'Matt Belisle': 5,
#  'Tyler Duffey': 5,
#  'Taylor Rogers': 5,
#  'Aaron Slegers': 5,
#  'Trevor Hildenberger': 5,
#  'Addison Reed': 6,
#  'Adalberto Mejia': 6,
#  'Ervin Santana': 6,
#  'Kyle Gibson': 6,
#  'Jake Odorizzi': 6,
#  'Jose Berrios': 6,
#  'Thyago Vieira': 4,
#  'Tyler Danish': 3,
#  'Asher Wojciechowski': 3,
#  'Mauricio Cabrera': 3,
#  'Jace Fry': 4,
#  'Jeanmar Gomez': 5,
#  'Ricardo Pinto': 4,
#  'Rob Scahill': 3,
#  'Aaron Bummer': 4,
#  'Michael Ynoa': 3,
#  'Danny Farquhar': 5,
#  'Robbie Ross Jr.': 4,
#  'Dylan Covey': 5,
#  'Nate Jones': 5,
#  'Gregory Infante': 5,
#  'Michael Kopech': 5,
#  'Juan Minaya': 5,
#  'Hector Santiago': 5,
#  'Carlos Rodon': 5,
#  'Carson Fulmer': 5,
#  'Miguel Gonzalez': 5,
#  'Reynaldo Lopez': 6,
#  'Lucas Giolito': 6,
#  'James Shields': 5,
#  'Chance Adams': 3,
#  'Ben Heller': 4,
#  'Domingo German': 4,
#  'Zach Britton': 5,
#  'Jonathan Holder': 4,
#  'Nestor Cortes': 4,
#  'Luis Cessa': 5,
#  'Tommy Kahnle': 6,
#  'Aroldis Chapman': 6,
#  'George Kontos': 5,
#  'Dellin Betances': 6,
#  'David Robertson': 6,
#  'Chad Green': 6,
#  'A.J. Cole': 5,
#  'CC Sabathia': 6,
#  'Jordan Montgomery': 6,
#  'Sonny Gray': 6,
#  'J.A. Happ': 6,
#  'Masahiro Tanaka': 6,
#  'Lance Lynn': 6,
#  'Luis Severino': 6,
#  'Jonny Venters': 3,
#  'Kris Medlen': 4,
#  'Dan Slania': 4,
#  'Pierce Johnson': 4,
#  'Adam Cimber': 3,
#  'Erasmo Ramirez': 5,
#  'David Hess': 4,
#  'Enyel De Los Santos': 4,
#  'Luis Garcia': 4,
#  'Ariel Jurado': 4,
#  'Jalen Beeks': 4,
#  'Justin Haley': 4,
#  'Sam Howard': 4,
#  'Heath Fillmyer': 4,
#  'Jaime Barria': 3,
#  'Jake Jewell': 3,
#  'Cionel Perez': 3,
#  'Dean Deetz': 3,
#  'Lou Trivino': 3,
#  'Adam McCreery': 3,
#  'Freddy Peralta': 3,
#  'Dennis Santana': 3,
#  'Trevor Richards': 3,
#  'Tyler Kinley': 3,
#  'Pablo Lopez': 3,
#  'Elieser Hernandez': 3,
#  'Brett Graves': 3,
#  'Corey Oswalt': 3,
#  'Pedro Araujo': 2,
#  'D.J. Snelten': 3,
#  'Eric Lauer': 3,
#  'Trey Wingenter': 3,
#  'Jose Castillo': 3,
#  'Brad Wieck': 3,
#  'Drew Anderson': 3,
#  'Ricardo Rodriguez': 3,
#  'Bobby Poyner': 3,
#  'Spencer Turnbull': 3,
#  'Zack Littell': 3,
#  'Jose Ruiz': 2,
#  'Jharel Cotton': 3,
#  'Osmer Morales': 2,
#  'Greg Mahle': 2,
#  'Justin Anderson': 1,
#  'Alex Meyer': 2,
#  'Framber Valdez': 2,
#  'Joshua James': 2,
#  'C.J. Riefenhauser': 1,
#  'Edwar Cabrera': 1,
#  'Darin Downs': 1,
#  'Jorge De Leon': 1,
#  'Edgar Gonzalez': 1,
#  'J.B. Wendelken': 1,
#  'Aaron Brooks': 2,
#  'Jeremy Bleich': 2,
#  'Sean Reid-Foley': 2,
#  'Justin Shafer': 2,
#  'Jose Fernandez': 1,
#  'Mike Hauschild': 2,
#  'Matthew Tracy': 2,
#  'Brandon Cumpton': 2,
#  'Murphy Smith': 2,
#  'Cesar Valdez': 2,
#  'Zach Stewart': 2,
#  'Preston Guilmet': 1,
#  'Jason Berken': 1,
#  'Arnold Leon': 1,
#  'Franklin Morales': 1,
#  'Gavin Floyd': 1,
#  'Matt Buschmann': 1,
#  'Ricky Romero': 1,
#  'Rafael Soriano': 1,
#  'Joel Pineiro': 1,
#  'Brad Penny': 1,
#  'Bryse Wilson': 1,
#  'Kolby Allard': 2,
#  'Michael Soroka': 2,
#  'Chad Sobotka': 1,
#  'Touki Toussaint': 2,
#  'Wes Parsons': 2,
#  'Jed Bradley': 1,
#  'Grant Dayton': 2,
#  'Alex White': 1,
#  'Michael Kirkman': 1,
#  'Nick Masset': 1,
#  'Miguel Socolovich': 2,
#  'Kameron Loe': 1,
#  'Greg Smith': 1,
#  'Jordan Walden': 1,
#  'Freddy Garcia': 1,
#  'Kanekoa Texeira': 1,
#  'Corbin Burnes': 2,
#  'Andrew Oliver': 2,
#  'Ariel Pena': 1,
#  'Mike Zagurski': 2,
#  'Hiram Burgos': 2,
#  'Erik Davis': 2,
#  'Tim Dillard': 2,
#  'Cesar Jimenez': 1,
#  'Jason Lane': 1,
#  'Jordan Hicks': 1,
#  'Dakota Hudson': 2,
#  'Daniel Poncedeleon': 2,
#  'Kendry Flores': 1,
#  'John Gast': 1,
#  'Tommy Layne': 2,
#  'Edward Mujica': 2,
#  'Jerome Williams': 1,
#  'James Norwood': 1,
#  'Justin Hancock': 2,
#  'Casey Coleman': 1,
#  'Anthony Bass': 2,
#  'Allen Webster': 2,
#  'Yoan Lopez': 2,
#  'Steve Hathaway': 1,
#  'Joey Krehbiel': 2,
#  'Jake Buchanan': 2,
#  'Michael Blazek': 2,
#  'Bradin Hagens': 1,
#  'Anthony Vasquez': 2,
#  'Matt Capps': 1,
#  'Kyle Drabek': 1,
#  'David Carpenter': 1,
#  'Barry Enright': 2,
#  'Caleb Ferguson': 1,
#  'Jesen Therrien': 2,
#  'Layne Somsen': 1,
#  'Dylan Floro': 2,
#  'Daniel Corcino': 2,
#  'Kyle Lobstein': 2,
#  'Manny Banuelos': 2,
#  'Chris Perez': 1,
#  'Justin De Fratus': 2,
#  'Brian Schlitter': 1,
#  'Dustin Richardson': 1,
#  'Jamey Wright': 1,
#  'Andrew Suarez': 2,
#  'Dereck Rodriguez': 2,
#  'Ray Black': 1,
#  'Taylor Hill': 2,
#  'Casey Kelly': 2,
#  'Guillermo Moscoso': 1,
#  'Matt Cain': 2,
#  'Manny Parra': 2,
#  'Chad Gaudin': 1,
#  'Shane Bieber': 2,
#  'Evan Marshall': 2,
#  'Preston Claiborne': 2,
#  'Alexi Ogando': 2,
#  'Stephen Fife': 2,
#  'Joseph Colon': 2,
#  'Jon Edwards': 1,
#  'Bruce Chen': 1,
#  'Matthew Festa': 1,
#  'David Rollins': 2,
#  'Mayckol Guaipe': 1,
#  'Williams Perez': 2,
#  'Rob Rasmussen': 1,
#  'Ryan Cook': 1,
#  'Daniel Schlereth': 2,
#  'Jean Machi': 2,
#  'Ross Detwiler': 2,
#  'Ben Meyer': 1,
#  'Merandy Gonzalez': 2,
#  'Jeff Brigham': 1,
#  'Nick Maronde': 1,
#  'Mike Kickham': 2,
#  'Pat Misch': 1,
#  'Jo-Jo Reyes': 1,
#  'Alex Sanabia': 1,
#  'Andre Rienzo': 2,
#  'Eric Hanhold': 1,
#  'P.J. Conlon': 2,
#  'Daniel Zamora': 1,
#  'Drew Smith': 2,
#  'Bobby Wahl': 2,
#  'Tim Peterson': 2,
#  'Drew Gagnon': 2,
#  'Scott Copeland': 2,
#  'Jenrry Mejia': 1,
#  'Mitch Atkins': 2,
#  'Jonathan Albaladejo': 2,
#  'Jefry Rodriguez': 2,
#  'Austen Williams': 2,
#  'Jimmy Cordero': 2,
#  'Kyle McGowin': 2,
#  'Chris Smith': 2,
#  'Cesar Vargas': 2,
#  'David Goforth': 2,
#  'Logan Darnell': 2,
#  'Aaron Barrett': 2,
#  'Roman Mendez': 2,
#  'Rafael Martin': 2,
#  'Justin Miller': 2,
#  'John Lannan': 1,
#  'Tim Collins': 2,
#  'Josh Rogers': 2,
#  'Ryan Meisinger': 2,
#  'Evan Phillips': 1,
#  'Cody Carroll': 2,
#  'Luis Ortiz': 2,
#  'Paul Fry': 1,
#  'Yefry Ramirez': 2,
#  "Ryan O'Rourke": 1,
#  'Perci Garner': 2,
#  'Chris Dwyer': 1,
#  'Eddie Gamboa': 2,
#  'Jairo Asencio': 1,
#  'Joey Lucchesi': 2,
#  'Brett Kennedy': 2,
#  'Jacob Nix': 2,
#  'Kyle Lloyd': 2,
#  'Erik Johnson': 1,
#  'Jose Dominguez': 1,
#  'Paul Clemens': 1,
#  'Robert Stock': 2,
#  'Jered Weaver': 2,
#  'Hector Ambriz': 1,
#  'Seranthony Dominguez': 2,
#  'Ranger Suarez': 2,
#  'Austin Davis': 2,
#  'Tanner Anderson': 2,
#  'Alex McRae': 2,
#  'Richard Rodriguez': 2,
#  'Kelvin Marte': 2,
#  'Bo Schultz': 1,
#  'Cory Luebke': 2,
#  'Ryan Vogelsong': 1,
#  'Zach Phillips': 1,
#  'C.D. Pelham': 1,
#  'Jeffrey Springs': 1,
#  'Tyler Wagner': 1,
#  'Adrian Sampson': 1,
#  'Jaye Chapman': 1,
#  'Brandon Mann': 2,
#  'Edinson Volquez': 2,
#  'Zeke Spruill': 1,
#  'Jose De Leon': 2,
#  'Zach Lee': 2,
#  'Adam Kolarek': 2,
#  'Jordan Norberto': 1,
#  'Evan Scribner': 2,
#  'Josh Lueke': 1,
#  'Kyle McPherson': 1,
#  'J.D. Martin': 1,
#  'Cory Rasmus': 1,
#  'Ronald Belisario': 1,
#  'Erik Bedard': 1,
#  'William Cuevas': 2,
#  'Elih Villanueva': 2,
#  'Marcus Walden': 2,
#  'Fernando Rodriguez': 1,
#  'Cesar Cabral': 1,
#  'Ryan Brasier': 1,
#  'Jess Todd': 1,
#  'Anthony Varvaro': 1,
#  'Denny Bautista': 1,
#  'Jose De La Torre': 1,
#  'Jesus Reyes': 1,
#  'Tanner Rainey': 2,
#  'Jon Moscot': 1,
#  'Alejandro Chacin': 2,
#  'Abel De Los Santos': 2,
#  'Andrew McKirahan': 1,
#  'Pedro Villarreal': 1,
#  'Rob Wooten': 2,
#  'Daniel Cabrera': 1,
#  'Harrison Musgrave': 2,
#  'D.J. Johnson': 1,
#  'Keith Hessler': 1,
#  'Scott McGough': 2,
#  'Sean Nolin': 1,
#  'Aaron Laffey': 2,
#  'Yohan Flande': 1,
#  'Manny Corpas': 1,
#  'Jerry Vasto': 1,
#  'Tim Hill': 2,
#  'Brad Keller': 2,
#  'Glenn Sparkman': 2,
#  'Jake Newberry': 2,
#  'Aaron Crow': 1,
#  'Brian Broderick': 1,
#  'Brandon League': 1,
#  'Clayton Mortensen': 2,
#  'Matt Hall': 2,
#  'Kevin Chapman': 1,
#  'Caleb Thielbar': 1,
#  'Louis Coleman': 2,
#  'Arcenio Leon': 2,
#  'Matt West': 1,
#  'Waldis Joaquin': 1,
#  'Phillippe Aumont': 2,
#  'Jacob Brigham': 1,
#  'Andrew Vasquez': 1,
#  'Kohl Stewart': 2,
#  'Jim Miller': 1,
#  'Mark Hamburger': 1,
#  'Matt Magill': 2,
#  'Josh Roenicke': 1,
#  'Ian Hamilton': 1,
#  'Ryan Burr': 1,
#  'Caleb Frare': 1,
#  'Tyler Matzek': 1,
#  'Blake Smith': 1,
#  'Dustin Antolin': 2,
#  'Gonzalez Germen': 1,
#  'Maikel Cleto': 1,
#  'Justus Sheffield': 2,
#  'Stephen Tarpley': 1,
#  'Jose De Paula': 1,
#  'Josh Outman': 1,
#  'Christian Bethancourt': 1,
#  'Anthony Gose': 1,
#  'Hernan Iribarren': 1,
#  'Chris Gimenez': 1}

# %% [markdown]
# ### Select names with 3+ projections

# %%
# create a list to store the names of players without 3+ projections. Add those players to that list, and remove those players from the original list of names
notEnoughEntries = []
for name in nameCounter:
    if nameCounter[name] < 3:
        notEnoughEntries.append(name)
        names.remove(name)
notEnoughEntries
# Out:
# ['Jose Valdez',
#  'Jon Niese',
#  'Brett Oberholtzer',
#  'Pedro Araujo',
#  'Jose Ruiz',
#  'Osmer Morales',
#  'Greg Mahle',
#  'Justin Anderson',
#  'Alex Meyer',
#  'Framber Valdez',
#  'Joshua James',
#  'C.J. Riefenhauser',
#  'Edwar Cabrera',
#  'Darin Downs',
#  'Jorge De Leon',
#  'Edgar Gonzalez',
#  'J.B. Wendelken',
#  'Aaron Brooks',
#  'Jeremy Bleich',
#  'Sean Reid-Foley',
#  'Justin Shafer',
#  'Jose Fernandez',
#  'Mike Hauschild',
#  'Matthew Tracy',
#  'Brandon Cumpton',
#  'Murphy Smith',
#  'Cesar Valdez',
#  'Zach Stewart',
#  'Preston Guilmet',
#  'Jason Berken',
#  'Arnold Leon',
#  'Franklin Morales',
#  'Gavin Floyd',
#  'Matt Buschmann',
#  'Ricky Romero',
#  'Rafael Soriano',
#  'Joel Pineiro',
#  'Brad Penny',
#  'Bryse Wilson',
#  'Kolby Allard',
#  'Michael Soroka',
#  'Chad Sobotka',
#  'Touki Toussaint',
#  'Wes Parsons',
#  'Jed Bradley',
#  'Grant Dayton',
#  'Alex White',
#  'Michael Kirkman',
#  'Nick Masset',
#  'Miguel Socolovich',
#  'Kameron Loe',
#  'Greg Smith',
#  'Jordan Walden',
#  'Freddy Garcia',
#  'Kanekoa Texeira',
#  'Corbin Burnes',
#  'Andrew Oliver',
#  'Ariel Pena',
#  'Mike Zagurski',
#  'Hiram Burgos',
#  'Erik Davis',
#  'Tim Dillard',
#  'Cesar Jimenez',
#  'Jason Lane',
#  'Jordan Hicks',
#  'Dakota Hudson',
#  'Daniel Poncedeleon',
#  'Kendry Flores',
#  'John Gast',
#  'Tommy Layne',
#  'Edward Mujica',
#  'Jerome Williams',
#  'James Norwood',
#  'Justin Hancock',
#  'Casey Coleman',
#  'Anthony Bass',
#  'Allen Webster',
#  'Yoan Lopez',
#  'Steve Hathaway',
#  'Joey Krehbiel',
#  'Jake Buchanan',
#  'Michael Blazek',
#  'Bradin Hagens',
#  'Anthony Vasquez',
#  'Matt Capps',
#  'Kyle Drabek',
#  'David Carpenter',
#  'Barry Enright',
#  'Caleb Ferguson',
#  'Jesen Therrien',
#  'Layne Somsen',
#  'Dylan Floro',
#  'Daniel Corcino',
#  'Kyle Lobstein',
#  'Manny Banuelos',
#  'Chris Perez',
#  'Justin De Fratus',
#  'Brian Schlitter',
#  'Dustin Richardson',
#  'Jamey Wright',
#  'Andrew Suarez',
#  'Dereck Rodriguez',
#  'Ray Black',
#  'Taylor Hill',
#  'Casey Kelly',
#  'Guillermo Moscoso',
#  'Matt Cain',
#  'Manny Parra',
#  'Chad Gaudin',
#  'Shane Bieber',
#  'Evan Marshall',
#  'Preston Claiborne',
#  'Alexi Ogando',
#  'Stephen Fife',
#  'Joseph Colon',
#  'Jon Edwards',
#  'Bruce Chen',
#  'Matthew Festa',
#  'David Rollins',
#  'Mayckol Guaipe',
#  'Williams Perez',
#  'Rob Rasmussen',
#  'Ryan Cook',
#  'Daniel Schlereth',
#  'Jean Machi',
#  'Ross Detwiler',
#  'Ben Meyer',
#  'Merandy Gonzalez',
#  'Jeff Brigham',
#  'Nick Maronde',
#  'Mike Kickham',
#  'Pat Misch',
#  'Jo-Jo Reyes',
#  'Alex Sanabia',
#  'Andre Rienzo',
#  'Eric Hanhold',
#  'P.J. Conlon',
#  'Daniel Zamora',
#  'Drew Smith',
#  'Bobby Wahl',
#  'Tim Peterson',
#  'Drew Gagnon',
#  'Scott Copeland',
#  'Jenrry Mejia',
#  'Mitch Atkins',
#  'Jonathan Albaladejo',
#  'Jefry Rodriguez',
#  'Austen Williams',
#  'Jimmy Cordero',
#  'Kyle McGowin',
#  'Chris Smith',
#  'Cesar Vargas',
#  'David Goforth',
#  'Logan Darnell',
#  'Aaron Barrett',
#  'Roman Mendez',
#  'Rafael Martin',
#  'Justin Miller',
#  'John Lannan',
#  'Tim Collins',
#  'Josh Rogers',
#  'Ryan Meisinger',
#  'Evan Phillips',
#  'Cody Carroll',
#  'Luis Ortiz',
#  'Paul Fry',
#  'Yefry Ramirez',
#  "Ryan O'Rourke",
#  'Perci Garner',
#  'Chris Dwyer',
#  'Eddie Gamboa',
#  'Jairo Asencio',
#  'Joey Lucchesi',
#  'Brett Kennedy',
#  'Jacob Nix',
#  'Kyle Lloyd',
#  'Erik Johnson',
#  'Jose Dominguez',
#  'Paul Clemens',
#  'Robert Stock',
#  'Jered Weaver',
#  'Hector Ambriz',
#  'Seranthony Dominguez',
#  'Ranger Suarez',
#  'Austin Davis',
#  'Tanner Anderson',
#  'Alex McRae',
#  'Richard Rodriguez',
#  'Kelvin Marte',
#  'Bo Schultz',
#  'Cory Luebke',
#  'Ryan Vogelsong',
#  'Zach Phillips',
#  'C.D. Pelham',
#  'Jeffrey Springs',
#  'Tyler Wagner',
#  'Adrian Sampson',
#  'Jaye Chapman',
#  'Brandon Mann',
#  'Edinson Volquez',
#  'Zeke Spruill',
#  'Jose De Leon',
#  'Zach Lee',
#  'Adam Kolarek',
#  'Jordan Norberto',
#  'Evan Scribner',
#  'Josh Lueke',
#  'Kyle McPherson',
#  'J.D. Martin',
#  'Cory Rasmus',
#  'Ronald Belisario',
#  'Erik Bedard',
#  'William Cuevas',
#  'Elih Villanueva',
#  'Marcus Walden',
#  'Fernando Rodriguez',
#  'Cesar Cabral',
#  'Ryan Brasier',
#  'Jess Todd',
#  'Anthony Varvaro',
#  'Denny Bautista',
#  'Jose De La Torre',
#  'Jesus Reyes',
#  'Tanner Rainey',
#  'Jon Moscot',
#  'Alejandro Chacin',
#  'Abel De Los Santos',
#  'Andrew McKirahan',
#  'Pedro Villarreal',
#  'Rob Wooten',
#  'Daniel Cabrera',
#  'Harrison Musgrave',
#  'D.J. Johnson',
#  'Keith Hessler',
#  'Scott McGough',
#  'Sean Nolin',
#  'Aaron Laffey',
#  'Yohan Flande',
#  'Manny Corpas',
#  'Jerry Vasto',
#  'Tim Hill',
#  'Brad Keller',
#  'Glenn Sparkman',
#  'Jake Newberry',
#  'Aaron Crow',
#  'Brian Broderick',
#  'Brandon League',
#  'Clayton Mortensen',
#  'Matt Hall',
#  'Kevin Chapman',
#  'Caleb Thielbar',
#  'Louis Coleman',
#  'Arcenio Leon',
#  'Matt West',
#  'Waldis Joaquin',
#  'Phillippe Aumont',
#  'Jacob Brigham',
#  'Andrew Vasquez',
#  'Kohl Stewart',
#  'Jim Miller',
#  'Mark Hamburger',
#  'Matt Magill',
#  'Josh Roenicke',
#  'Ian Hamilton',
#  'Ryan Burr',
#  'Caleb Frare',
#  'Tyler Matzek',
#  'Blake Smith',
#  'Dustin Antolin',
#  'Gonzalez Germen',
#  'Maikel Cleto',
#  'Justus Sheffield',
#  'Stephen Tarpley',
#  'Jose De Paula',
#  'Josh Outman',
#  'Christian Bethancourt',
#  'Anthony Gose',
#  'Hernan Iribarren',
#  'Chris Gimenez']

# %% [markdown]
# ### Remove projections of players that have less than 3 different projections

# %%
for name in notEnoughEntries:
    projections = projections[projections.Name != name]

# %%
projections
# Out:
#                  Name     Team  Type   W  L   ERA  GS   G     IP    H  ER  HR  \
# 0      Williams Jerez   Angels   ATC   0  0  4.64   0   5    6.0    6   3   1
# 1         Jason Gurka   Angels   ATC   1  0  4.33   0  18   11.0   15   5   1
# 2          Ty Buttrey   Angels   ATC   1  1  4.92   0  11   12.0   12   6   2
# 3           John Lamb   Angels   ATC   1  1  5.72   1   3   14.0   17   9   2
# 4        Akeel Morris   Angels   ATC   0  1  4.25   0  16   16.0   15   8   3
# 5          Dayan Diaz   Angels   ATC   1  1  4.72   0  14   16.0   16   9   3
# 6      Miguel Almonte   Angels   ATC   0  0  4.84   1  11   18.0   19  10   2
# 7        Deck McGuire   Angels   ATC   1  1  4.65   1   8   20.0   20  10   2
# 8         Taylor Cole   Angels   ATC   0  1  7.36   1  18   21.0   30  17   1
# 9         Noe Ramirez   Angels   ATC   1  1  3.95   0  25   27.0   23  12   5
# 10    Eduardo Paredes   Angels   ATC   1  1  4.07   0  24   28.0   26  13   4
# 11         Felix Pena   Angels   ATC   1  0  4.66   0  24   29.0   26  15   6
# ...               ...      ...   ...  .. ..   ...  ..  ..    ...  ...  ..  ..
# 3804       Luis Cessa  Yankees  ZiPS   7  8  5.21  20  25  115.7  124  67  22
# 3805       Sonny Gray  Yankees  ZiPS  13  9  3.80  28  28  168.3  151  71  20
# 3806        A.J. Cole  Yankees  ZiPS   8  8  4.97  25  27  137.7  149  76  24
# 3807     Tommy Kahnle  Yankees  ZiPS   3  2  3.13   0  63   60.3   46  21   5
# 3808  Aroldis Chapman  Yankees  ZiPS   5  2  2.41   0  54   52.3   34  14   4
# 3809    George Kontos  Yankees  ZiPS   4  3  3.71   0  60   60.7   57  25   7
# 3810  David Robertson  Yankees  ZiPS   7  3  2.72   0  57   59.7   42  18   6
# 3811        J.A. Happ  Yankees  ZiPS  11  8  3.87  25  25  142.0  137  61  17
# 3812  Dellin Betances  Yankees  ZiPS   6  3  2.97   0  65   60.7   41  20   5
# 3813     Zach Britton  Yankees  ZiPS   2  1  2.89   0  55   53.0   44  17   2
# 3814       Lance Lynn  Yankees  ZiPS  11  9  3.82  31  31  169.7  165  72  20
# 3815      CC Sabathia  Yankees  ZiPS   9  8  4.37  24  24  131.7  136  64  19
#
#        SO  BB  WHIP    K/9  BB/9   FIP    ADP  playerid
# 0       5   3  1.52   7.21  4.52  4.53  999.0     14338
# 1      10   5  1.77   8.02  3.89  3.47  999.0      8007
# 2       9   6  1.57   7.23  4.96  4.96  999.0     14719
# 3      10   5  1.58   6.20  3.29  5.17  999.0      8493
# 4      18   9  1.47  10.01  5.06  5.22  999.0     12185
# 5      15   7  1.42   8.52  3.75  4.71  999.0     11543
# 6      16   8  1.52   8.22  4.15  4.31  999.0     14139
# 7      16   8  1.41   7.29  3.54  4.51  999.0     11596
# 8      16   8  1.83   6.88  3.27  3.84  999.0     11964
# 9      28  11  1.27   9.37  3.67  4.72  999.0     12800
# 10     26  12  1.36   8.36  3.80  4.79  999.0     16344
# 11     31  13  1.35   9.83  3.93  4.94  999.0     13403
# ...   ...  ..   ...    ...   ...   ...    ...       ...
# 3804   93  40  1.42   7.24  3.11  5.22  999.0     13345
# 3805  157  54  1.22   8.39  2.89  3.85  139.6     12768
# 3806  111  51  1.45   7.26  3.33  5.08  527.4     11467
# 3807   82  28  1.23  12.23  4.18  2.96  454.8     11384
# 3808   82  23  1.09  14.10  3.96  2.45   63.2     10233
# 3809   54  18  1.24   8.01  2.67  3.82  681.2      9486
# 3810   86  21  1.06  12.97  3.17  2.74  306.5      8241
# 3811  127  43  1.27   8.05  2.73  3.88  249.0      7410
# 3812   92  36  1.27  13.65  5.34  3.27  280.8      6216
# 3813   51  20  1.21   8.66  3.40  2.86  299.7      3240
# 3814  145  69  1.38   7.69  3.66  4.32  221.2      2520
# 3815  107  43  1.36   7.31  2.94  4.52  332.7       404
#
# [3395 rows x 20 columns]

# %% [markdown]
# ### Create an average of all projections for each player and add to table

# %%
cols = projections.columns.values.tolist()

for name in names:
    currentPlayer = projections.loc[projections['Name'] == name]
    # set name, team, projection type
    playerName = currentPlayer["Name"].values.tolist()[0]
    team = currentPlayer["Team"].values.tolist()[0]
    projectionType = "A-Average" # the name 'A-Average' is solely for sorting purposes- want the average projections to appear first later on
    # calculate average wins
    w = currentPlayer["W"].values.tolist()
    total = 0
    for i in w:
        total = total + i
    average = total / len(w)
    w = int(round(average))
    # calculate average losses
    l = currentPlayer["L"].values.tolist()
    total = 0
    for i in l:
        total = total + i
    average = total / len(l)
    l = int(round(average))
    # calculate average earned run average
    era = currentPlayer["ERA"].values.tolist()
    total = 0
    for i in era:
        total = total + i
    average = total / len(era)
    era = int(round(average, 2))
    # calculate average games started
    gs = currentPlayer["GS"].values.tolist()
    total = 0
    for i in gs:
        total = total + i
    average = total / len(gs)
    gs = int(round(average))
    # calculate average games
    g = currentPlayer["G"].values.tolist()
    total = 0
    for i in g:
        total = total + i
    average = total / len(g)
    g = int(round(average))
    # calculate average innings pitched
    ip = currentPlayer["IP"].values.tolist()
    total = 0
    for i in ip:
        total = total + i
    average = total / len(ip)
    ip = int(round(average))
    # calculate average hits
    h = currentPlayer["H"].values.tolist()
    total = 0
    for i in h:
        total = total + i
    average = total / len(h)
    h = int(round(average))
    # calculate average earned runs
    er = currentPlayer["ER"].values.tolist()
    total = 0
    for i in er:
        total = total + i
    average = total / len(er)
    er = int(round(average))
    # calculate average home runs
    hr = currentPlayer["HR"].values.tolist()
    total = 0
    for i in hr:
        total = total + i
    average = total / len(hr)
    hr = int(round(average))
    # calculate average strikeouts
    so = currentPlayer["SO"].values.tolist()
    total = 0
    for i in so:
        total = total + i
    average = total / len(so)
    so = int(round(average))
    # calculate average walks
    bb = currentPlayer["BB"].values.tolist()
    total = 0
    for i in bb:
        total = total + i
    average = total / len(bb)
    bb = int(round(average))
    # calculate average walks and hits per inning
    whip = currentPlayer["WHIP"].values.tolist()
    total = 0
    for i in whip:
        total = total + i
    average = total / len(whip)
    whip = int(round(average))
    # calculate average strikeouts per 9 innings
    k9 = currentPlayer["K/9"].values.tolist()
    total = 0
    for i in k9:
        total = total + i
    average = total / len(k9)
    k9 = int(round(average))
    # calculate average walks per 9 innings
    bb9 = currentPlayer["BB/9"].values.tolist()
    total = 0
    for i in bb9:
        total = total + i
    average = total / len(bb9)
    bb9 = int(round(average))
    # calculate average fielding independent hitting
    fip = currentPlayer["FIP"].values.tolist()
    total = 0
    for i in fip:
        total = total + i
    average = total / len(fip)
    fip = int(round(average))
    # calculate average hits
    h = currentPlayer["H"].values.tolist()
    total = 0
    for i in h:
        total = total + i
    average = total / len(h)
    h = int(round(average))
    #set average draft position, player ID
    adp = currentPlayer["ADP"].values.tolist()[0]
    playerID = currentPlayer["playerid"].values.tolist()[0]
    
    #create dataframe of new entry with average projections
    newEntry = [playerName, team, projectionType, w, l, era, gs, g, ip, h, er, hr, so, bb, whip, k9, bb9, fip, adp, playerID]
    newEntry = pd.DataFrame([newEntry], columns=cols)
    
    #append new entry to projections
    projections = projections.append(newEntry)

# %%
 projections = projections.sort_values(by=["Name", "Team", "Type"])

# %%
projections
# Out:
#               Name          Team          Type   W   L   ERA  GS   G     IP  \
# 0        A.J. Cole       Yankees     A-Average   5   5  4.00  15  16   86.0
# 673      A.J. Cole       Yankees           ATC   6   7  4.78  19  19  100.0
# 1829     A.J. Cole       Yankees  Depth Charts   4   4  4.88  11  11   65.0
# 2946     A.J. Cole       Yankees       Steamer   4   4  4.79  11  11   63.0
# 1197     A.J. Cole       Yankees       The Bat   3   4  5.43  11  11   65.0
# 3806     A.J. Cole       Yankees          ZiPS   8   8  4.97  25  27  137.7
# 0      A.J. Minter        Braves     A-Average   3   2  3.00   0  53   52.0
# 110    A.J. Minter        Braves           ATC   2   3  3.36   0  61   58.0
# 1300   A.J. Minter        Braves  Depth Charts   3   2  3.30   0  55   55.0
# 2109   A.J. Minter        Braves       Steamer   3   2  3.29   0  55   55.0
# 757    A.J. Minter        Braves       The Bat   3   3  3.34   0  55   55.0
# 3079   A.J. Minter        Braves          ZiPS   2   1  3.32   0  41   38.0
# ...            ...           ...           ...  ..  ..   ...  ..  ..    ...
# 863   Zack Greinke  Diamondbacks       The Bat  13  11  3.62  32  32  204.0
# 3232  Zack Greinke  Diamondbacks          ZiPS  14   8  3.48  28  28  175.7
# 0     Zack Littell         Twins     A-Average   3   4  4.00   8  16   54.0
# 1780  Zack Littell         Twins  Depth Charts   1   1  4.56   0  10   10.0
# 2875  Zack Littell         Twins       Steamer   0   0  4.26   0  10   10.0
# 3744  Zack Littell         Twins          ZiPS   9  10  4.86  25  27  142.7
# 0     Zack Wheeler          Mets     A-Average   6   7  4.00  17  28  109.0
# 357   Zack Wheeler          Mets           ATC   5   9  4.47  21  29  117.0
# 1538  Zack Wheeler          Mets  Depth Charts   6   7  4.44  16  31  112.0
# 2482  Zack Wheeler          Mets       Steamer   6   7  4.16  16  31  104.0
# 963   Zack Wheeler          Mets       The Bat   6   7  4.25  16  31  112.0
# 3406  Zack Wheeler          Mets          ZiPS   5   7  4.71  16  16   99.3
#
#         H  ER  HR   SO  BB  WHIP    K/9  BB/9   FIP    ADP  playerid
# 0      92  47  15   71  34  1.00   7.00  4.00  5.00  527.4     11467
# 673   106  53  16   88  41  1.47   7.86  3.72  4.91  527.4     11467
# 1829   68  35  11   53  25  1.44   7.42  3.47  4.97  527.4     11467
# 2946   65  34  10   54  25  1.42   7.60  3.61  4.85  527.4     11467
# 1197   72  39  12   51  26  1.51   7.08  3.63  5.30  527.4     11467
# 3806  149  76  24  111  51  1.45   7.26  3.33  5.08  527.4     11467
# 0      42  19   5   69  21  1.00  12.00  4.00  3.00  365.7     18655
# 110    45  22   5   82  22  1.15  12.79  3.42  2.62  365.7     18655
# 1300   44  20   6   73  22  1.20  11.94  3.67  3.20  365.7     18655
# 2109   44  20   6   71  23  1.22  11.56  3.79  3.35  365.7     18655
# 757    45  20   6   68  21  1.19  11.18  3.38  3.38  365.7     18655
# 3079   30  14   4   52  15  1.18  12.32  3.55  3.05  365.7     18655
# ...   ...  ..  ..  ...  ..   ...    ...   ...   ...    ...       ...
# 863   186  82  24  198  60  1.21   8.75  2.64  3.69   49.0      1943
# 3232  160  68  22  170  40  1.14   8.71  2.05  3.55   49.0      1943
# 0      60  29   8   40  17  1.00   7.00  3.00  5.00  999.0     15823
# 1780   11   5   1    8   3  1.39   6.97  2.84  4.59  999.0     15823
# 2875   10   5   1    8   3  1.33   7.44  2.78  4.30  999.0     15823
# 3744  160  77  22  103  46  1.44   6.50  2.90  4.87  999.0     15823
# 0     107  53  15  103  46  1.00   9.00  4.00  4.00  428.0     10310
# 357   118  58  18  111  51  1.45   8.52  3.94  4.64  428.0     10310
# 1538  109  55  15  107  46  1.38   8.62  3.67  4.39  428.0     10310
# 2482  100  48  13  100  42  1.36   8.63  3.63  4.16  428.0     10310
# 963   109  53  14  101  48  1.40   8.14  3.83  4.41  428.0     10310
# 3406   97  52  15   95  41  1.39   8.61  3.71  4.60  428.0     10310
#
# [4112 rows x 20 columns]

# %% [markdown]
# ### Once the 2018 MLB season has completed, this workbook will be updated to include actual player stats from the season, along with additional computations and visualizations of how accurate each projection model was

# %% [markdown]
# ##### Notes to self-
# ##### Compare each projection to the player's actual stat line, see which projections tended to be most accurate
# ##### Consider reducing the scope of players to those that were going to play a full season- Results could be skewed from someone that was reasonably expected to play a full season but ended up not having much time in the MLB. Limit comparisons to players that pitched at least 50(?) innings this season and reasonably were expected to play that many?
# ##### Average how far each projection model was off for all players- i.e. if Scherzer's ZiPS projected 250 strikeouts and he actually had 300, and Sale's ZiPS projected 275 strikeouts and he actually had 250, overall ZiPS projection was off by 75 strikeouts- Think more if this would be worthwhile to look at league-wide, or for players with 50+ IP
# ##### Consider repeating this project for 2017, 2016, 2015, etc data to get an idea of historical accuracy for each predictive model
