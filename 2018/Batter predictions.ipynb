# %% [markdown]
# # Evaluating different projections of MLB statistics for 2018 season
# ##### The purpose of this project was to evaluate how well different models predicted a player's statistics for the 2018 MLB season. There are 6 different models evaluated in this project- ATC, Depth Charts, Fangraphs, Steamer, The Bat, ZiPS, and an average of those 5 projections. Raw data of each projection was downloaded via fangraphs.com and compressed into one standardized spreadsheet. Exact number of projections may vary from player to player as some projections excluded certain players from their projections.
# ##### This project is not fully complete as the 2018 MLB season has not yet completed. Currently, this workbook does some data cleansing, then data manipulation to calculate average projections before adding the average projection for each player to the table of projections. Upon completion of the 2018 MLB season, this workbook will be updated with each player's actual statistics from the season, along with some work and visualization to see how well each projection model did at predicting players' stats.

# %%
import pandas as pd
pd.set_option('display.max_columns', 50)
pd.set_option('display.max_rows', 25)

# %% [markdown]
# ### Load file

# %%
projections = pd.read_csv("2018-MLB-Projections-Hitters.csv")

# %%
projections.head(10)
# Out:
#            Name          Team          Type    G   PA   AB    H  2B  3B  HR  \
# 0    A.J. Ellis        Padres           ATC   32  114   99   22   4   0   3
# 1    A.J. Ellis        Padres       The Bat   40  158  138   33   6   1   4
# 2    A.J. Ellis        Padres  Depth Charts   38  160  140   31   6   0   4
# 3    A.J. Ellis        Padres       Steamer   33  129  112   26   5   0   4
# 4    A.J. Ellis        Padres          ZiPS   50  155  137   29   6   0   4
# 5  A.J. Pollock  Diamondbacks           ATC  141  586  533  150  36   7  16
# 6  A.J. Pollock  Diamondbacks       The Bat  143  619  557  155  36   5  18
# 7  A.J. Pollock  Diamondbacks  Depth Charts  147  616  557  160  38   6  19
# 8  A.J. Pollock  Diamondbacks     Fangraphs  130  591  534  152  35   5  16
# 9  A.J. Pollock  Diamondbacks       Steamer  124  559  500  141  33   5  17
#
#     R  RBI  BB  SO  HBP  SB  CS    AVG    OBP    SLG    OPS   wOBA  Fld  BsR  \
# 0   9   10  12  20  NaN   0   0  0.218  0.312  0.349  0.661  0.292  NaN  NaN
# 1  16   16  16  30  NaN   1   0  0.237  0.320  0.372  0.692  0.301  NaN  NaN
# 2  15   17  15  30  3.0   1   0  0.223  0.309  0.361  0.670  0.293  1.1 -0.7
# 3  13   13  14  25  2.0   1   1  0.234  0.323  0.379  0.702  0.307 -0.8  1.2
# 4  13   16  12  28  4.0   0   0  0.212  0.294  0.343  0.637  0.279  1.0 -0.1
# 5  88   60  45  86  NaN  28   7  0.281  0.341  0.463  0.803  0.342  NaN  NaN
# 6  83   76  53  92  NaN  22   7  0.278  0.344  0.456  0.801  0.342  NaN  NaN
# 7  92   68  48  92  5.0  26   9  0.287  0.347  0.480  0.827  0.351  4.4  1.9
# 8  96   64  49  89  4.0  26   5  0.285  0.347  0.459  0.806  0.344  5.0  2.7
# 9  80   61  47  85  4.0  22   9  0.282  0.346  0.469  0.815  0.347  1.2  2.3
#
#    WAR    ADP  playerid
# 0  NaN  999.0      5677
# 1  NaN  999.0      5677
# 2  0.5  999.0      5677
# 3  0.6  999.0      5677
# 4  0.3  999.0      5677
# 5  NaN   68.2      9256
# 6  NaN   68.2      9256
# 7  3.6   68.2      9256
# 8  3.2   68.2      9256
# 9  2.9   68.2      9256

# %%
projections.columns
# Out:
# Index(['Name', 'Team', 'Type', 'G', 'PA', 'AB', 'H', '2B', '3B', 'HR', 'R',
#        'RBI', 'BB', 'SO', 'HBP', 'SB', 'CS', 'AVG', 'OBP', 'SLG', 'OPS',
#        'wOBA', 'Fld', 'BsR', 'WAR', 'ADP', 'playerid'],
#       dtype='object')

# %% [markdown]
# ### Find columns with NaNs and remove

# %%
projections.columns[projections.isna().any()].tolist()
# Out:
# ['HBP', 'Fld', 'BsR', 'WAR']

# %%
projections = projections.drop(["HBP", "Fld", "BsR", "WAR"], axis=1)

# %%
projections.columns[projections.isna().any()].tolist()
# Out:
# []

# %%
projections.columns
# Out:
# Index(['Name', 'Team', 'Type', 'G', 'PA', 'AB', 'H', '2B', '3B', 'HR', 'R',
#        'RBI', 'BB', 'SO', 'SB', 'CS', 'AVG', 'OBP', 'SLG', 'OPS', 'wOBA',
#        'ADP', 'playerid'],
#       dtype='object')

# %%
projections.head()
# Out:
#          Name    Team          Type   G   PA   AB   H  2B  3B  HR   R  RBI  \
# 0  A.J. Ellis  Padres           ATC  32  114   99  22   4   0   3   9   10
# 1  A.J. Ellis  Padres       The Bat  40  158  138  33   6   1   4  16   16
# 2  A.J. Ellis  Padres  Depth Charts  38  160  140  31   6   0   4  15   17
# 3  A.J. Ellis  Padres       Steamer  33  129  112  26   5   0   4  13   13
# 4  A.J. Ellis  Padres          ZiPS  50  155  137  29   6   0   4  13   16
#
#    BB  SO  SB  CS    AVG    OBP    SLG    OPS   wOBA    ADP  playerid
# 0  12  20   0   0  0.218  0.312  0.349  0.661  0.292  999.0      5677
# 1  16  30   1   0  0.237  0.320  0.372  0.692  0.301  999.0      5677
# 2  15  30   1   0  0.223  0.309  0.361  0.670  0.293  999.0      5677
# 3  14  25   1   1  0.234  0.323  0.379  0.702  0.307  999.0      5677
# 4  12  28   0   0  0.212  0.294  0.343  0.637  0.279  999.0      5677

# %% [markdown]
# ### Create list of all player names that have projections, plus dictionary storing the number of different projections for each name
# ##### To make the average projections more worthwhile, I will only use players that had at least 3 projections

# %%
names = []
nameCounter = {}
for index, row in projections.iterrows():
    name = row["Name"]
    if name not in names:
        names.append(name)
        nameCounter[name] = 1
    else:
        nameCounter[name] += 1
print(len(names))
# Out:
# 712

# %%
nameCounter
# Out:
# {'A.J. Ellis': 5,
#  'A.J. Pollock': 6,
#  'A.J. Reed': 5,
#  'Aaron Altherr': 6,
#  'Aaron Hicks': 6,
#  'Aaron Judge': 6,
#  'Abiatal Avelino': 1,
#  'Adalberto Mondesi': 6,
#  'Adam Duvall': 6,
#  'Adam Eaton': 6,
#  'Adam Engel': 5,
#  'Adam Frazier': 6,
#  'Adam Jones': 6,
#  'Adam Moore': 1,
#  'Adam Rosales': 2,
#  'Addison Russell': 6,
#  'Adeiny Hechavarria': 5,
#  'Adolis Garcia': 1,
#  'Adrian Beltre': 6,
#  'Adrian Sanchez': 2,
#  'Albert Almora Jr.': 6,
#  'Albert Pujols': 6,
#  'Alberto Rosario': 2,
#  'Alcides Escobar': 6,
#  'Aledmys Diaz': 6,
#  'Alen Hanson': 2,
#  'Alex Avila': 6,
#  'Alex Blandino': 1,
#  'Alex Bregman': 6,
#  'Alex Dickerson': 2,
#  'Alex Gordon': 6,
#  'Alex Mejia': 2,
#  'Alex Verdugo': 5,
#  'Alfredo Gonzalez': 1,
#  'Ali Solis': 1,
#  'Allen Cordoba': 5,
#  'Allen Craig': 1,
#  'Amed Rosario': 6,
#  'Andrelton Simmons': 6,
#  'Andres Blanco': 2,
#  'Andrew Benintendi': 6,
#  'Andrew Knapp': 5,
#  'Andrew McCutchen': 6,
#  'Andrew Romine': 5,
#  'Andrew Stevenson': 5,
#  'Andrew Susac': 5,
#  'Andrew Toles': 5,
#  'Andy Wilkins': 1,
#  'Anthony Alford': 6,
#  'Anthony Recker': 1,
#  'Anthony Rendon': 6,
#  'Anthony Rizzo': 6,
#  'Anthony Santander': 5,
#  'Aramis Garcia': 1,
#  'Arismendy Alcantara': 1,
#  'Aristides Aquino': 1,
#  'Asdrubal Cabrera': 6,
#  'Audry Perez': 1,
#  'Austin Barnes': 6,
#  'Austin Dean': 1,
#  'Austin Hays': 5,
#  'Austin Hedges': 5,
#  'Austin Jackson': 6,
#  'Austin Meadows': 5,
#  'Austin Romine': 5,
#  'Austin Slater': 2,
#  'Austin Wynns': 1,
#  'Avisail Garcia': 6,
#  'Beau Taylor': 1,
#  'Ben Gamel': 6,
#  'Ben Zobrist': 6,
#  'Billy Burns': 2,
#  'Billy Hamilton': 6,
#  'Billy McKinney': 1,
#  'Blake Swihart': 6,
#  'Blake Trahan': 1,
#  'Bobby Wilson': 1,
#  'Boog Powell': 5,
#  'Bradley Zimmer': 6,
#  'Brandon Barnes': 1,
#  'Brandon Belt': 6,
#  'Brandon Crawford': 6,
#  'Brandon Dixon': 5,
#  'Brandon Drury': 5,
#  'Brandon Guyer': 5,
#  'Brandon Lowe': 1,
#  'Brandon Nimmo': 6,
#  'Brandon Phillips': 4,
#  'Brandon Snyder': 1,
#  'Braxton Lee': 4,
#  'Brett Eibner': 1,
#  'Brett Gardner': 6,
#  'Brett Nicholas': 2,
#  'Brett Phillips': 2,
#  'Breyvic Valera': 1,
#  'Brian Anderson': 4,
#  'Brian Dozier': 6,
#  'Brian Goodwin': 5,
#  'Brian McCann': 6,
#  'Brock Holt': 5,
#  'Brock Stassi': 1,
#  'Bruce Maxwell': 5,
#  'Bryan Holaday': 1,
#  'Bryce Brentz': 2,
#  'Bryce Harper': 6,
#  'Buster Posey': 6,
#  'Byron Buxton': 6,
#  'C.J. Cron': 6,
#  'Caleb Joseph': 5,
#  'Cam Gallagher': 5,
#  'Cam Perkins': 2,
#  'Cameron Maybin': 6,
#  'Cameron Rupp': 2,
#  'Carlos Asuaje': 5,
#  'Carlos Correa': 6,
#  'Carlos Gomez': 5,
#  'Carlos Gonzalez': 6,
#  'Carlos Moncrief': 1,
#  'Carlos Perez': 1,
#  'Carlos Rivero': 1,
#  'Carlos Santana': 6,
#  'Carlos Tocci': 5,
#  'Carson Kelly': 6,
#  'Cedric Mullins II': 1,
#  'Cesar Hernandez': 6,
#  'Cesar Puello': 2,
#  'Chad Huffman': 1,
#  'Chad Pinder': 5,
#  'Chad Wallach': 5,
#  'Chance Sisco': 5,
#  'Charlie Blackmon': 6,
#  'Charlie Culberson': 5,
#  'Charlie Tilson': 2,
#  "Chase d'Arnaud": 2,
#  'Chase Utley': 5,
#  'Cheslor Cuthbert': 5,
#  'Chris Coghlan': 1,
#  'Chris Davis': 6,
#  'Chris Dominguez': 1,
#  'Chris Gimenez': 3,
#  'Chris Herrmann': 2,
#  'Chris Iannetta': 6,
#  'Chris Marrero': 1,
#  'Chris Owings': 5,
#  'Chris Shaw': 1,
#  'Chris Stewart': 2,
#  'Chris Taylor': 6,
#  'Chris Young': 5,
#  'Christian Arroyo': 5,
#  'Christian Colon': 1,
#  'Christian Vazquez': 6,
#  'Christian Villanueva': 5,
#  'Christian Walker': 2,
#  'Christian Yelich': 6,
#  'Christin Stewart': 1,
#  'Christopher Bostick': 2,
#  'Cliff Pennington': 5,
#  'Clint Frazier': 6,
#  'Cody Asche': 1,
#  'Cody Bellinger': 6,
#  'Cody Decker': 1,
#  'Colby Rasmus': 5,
#  'Colin Moran': 6,
#  'Colin Walsh': 1,
#  'Collin Cowgill': 1,
#  'Corban Joseph': 1,
#  'Corey Dickerson': 6,
#  'Corey Seager': 6,
#  'Cory Spangenberg': 5,
#  'Cristhian Adames': 1,
#  'Curt Casali': 2,
#  'Curtis Granderson': 6,
#  'D.J. Stewart': 1,
#  'Dalton Pompey': 2,
#  'Dan Butler': 1,
#  'Dan Vogelbach': 6,
#  'Daniel Castro': 1,
#  'Daniel Descalso': 5,
#  'Daniel Muno': 1,
#  'Daniel Murphy': 6,
#  'Daniel Nava': 2,
#  'Daniel Palka': 1,
#  'Daniel Robertson': 4,
#  'Danny Espinosa': 2,
#  'Danny Jansen': 5,
#  'Danny Ortiz': 1,
#  'Danny Santana': 2,
#  'Dansby Swanson': 6,
#  'Darnell Sweeney': 1,
#  'Darwin Barney': 2,
#  'David Bote': 1,
#  'David Dahl': 6,
#  'David Fletcher': 1,
#  'David Freese': 5,
#  'David Freitas': 1,
#  'David Peralta': 6,
#  'David Wright': 1,
#  'Dawel Lugo': 5,
#  'Dee Gordon': 6,
#  'Delino DeShields': 6,
#  'Denard Span': 5,
#  'Derek Dietrich': 5,
#  'Derek Fisher': 6,
#  'Desmond Jennings': 1,
#  'Destin Hood': 1,
#  'Deven Marrero': 5,
#  'Devin Mesoraco': 6,
#  'Devon Travis': 6,
#  'Dexter Fowler': 6,
#  'Didi Gregorius': 6,
#  'Dilson Herrera': 2,
#  'Dixon Machado': 5,
#  'DJ LeMahieu': 6,
#  'Domingo Santana': 6,
#  'Dominic Smith': 5,
#  'Donovan Solano': 1,
#  'Drew Butera': 5,
#  'Drew Robinson': 5,
#  'Dustin Ackley': 1,
#  'Dustin Fowler': 5,
#  'Dustin Garneau': 2,
#  'Dustin Pedroia': 6,
#  'Dustin Peterson': 1,
#  'Dusty Coleman': 1,
#  'Dwight Smith Jr.': 2,
#  'Dylan Cozens': 5,
#  'Eddie Rosario': 6,
#  'Edmundo Sosa': 1,
#  'Eduardo Escobar': 6,
#  'Eduardo Nunez': 6,
#  'Edwin Encarnacion': 6,
#  'Ehire Adrianza': 6,
#  'Elias Diaz': 5,
#  'Elvis Andrus': 6,
#  'Emilio Bonifacio': 1,
#  'Ender Inciarte': 6,
#  'Engelb Vielma': 5,
#  'Enrique Hernandez': 5,
#  'Eric Haase': 1,
#  'Eric Hosmer': 6,
#  'Eric Thames': 6,
#  'Eric Young Jr.': 2,
#  'Erick Aybar': 2,
#  'Erik Gonzalez': 2,
#  'Erik Kratz': 2,
#  'Eugenio Suarez': 6,
#  'Eury Perez': 1,
#  'Evan Gattis': 6,
#  'Evan Longoria': 5,
#  'Everth Cabrera': 1,
#  'Ezequiel Carrera': 3,
#  'Franchy Cordero': 5,
#  'Francisco Cervelli': 5,
#  'Francisco Lindor': 6,
#  'Francisco Mejia': 5,
#  'Francisco Pena': 4,
#  'Franklin Barreto': 5,
#  'Franmil Reyes': 1,
#  'Freddie Freeman': 6,
#  'Freddy Galvis': 5,
#  'Gabriel Guerrero': 1,
#  'Garrett Cooper': 5,
#  'Garrett Hampson': 1,
#  'Gary Sanchez': 6,
#  'Gavin Cecchini': 5,
#  'George Springer': 6,
#  'Gerardo Parra': 5,
#  'Giancarlo Stanton': 6,
#  'Gift Ngoepe': 5,
#  'Giovanny Urshela': 5,
#  'Gleyber Torres': 6,
#  'Gordon Beckham': 2,
#  'Gorkys Hernandez': 5,
#  'Grayson Greiner': 1,
#  'Greg Allen': 2,
#  'Greg Bird': 6,
#  'Greg Garcia': 6,
#  'Gregor Blanco': 5,
#  'Gregorio Petit': 1,
#  'Gregory Polanco': 6,
#  'Guillermo Heredia': 6,
#  'Hanser Alberto': 4,
#  'Harrison Bader': 3,
#  'Henry Urrutia': 1,
#  'Hernan Iribarren': 1,
#  'Hernan Perez': 5,
#  'Howie Kendrick': 6,
#  'Hunter Dozier': 5,
#  'Hunter Pence': 6,
#  'Hunter Renfroe': 5,
#  'Ian Desmond': 6,
#  'Ian Happ': 6,
#  'Ian Kinsler': 6,
#  'Ildemaro Vargas': 2,
#  'Irving Falu': 1,
#  'Isaac Galloway': 1,
#  'Isiah Kiner-Falefa': 1,
#  'Ivan De Jesus': 1,
#  'J.B. Shuck': 1,
#  'J.D. Davis': 6,
#  'J.D. Martinez': 6,
#  'J.P. Crawford': 6,
#  'J.T. Realmuto': 6,
#  'J.T. Riddle': 5,
#  'Jabari Blash': 2,
#  'Jace Peterson': 2,
#  'Jack Reinheimer': 1,
#  'Jackie Bradley Jr.': 6,
#  'Jackson Williams': 1,
#  'Jacob Hannemann': 1,
#  'Jacob Nottingham': 1,
#  'Jacob Stallings': 5,
#  'Jacoby Ellsbury': 6,
#  'JaCoby Jones': 5,
#  'Jake Bauers': 5,
#  'Jake Cave': 4,
#  'Jake Elmore': 1,
#  'Jake Lamb': 6,
#  'Jake Marisnick': 6,
#  'Jake Smolinski': 5,
#  'James McCann': 5,
#  'Jarrod Dyson': 5,
#  'Jarrod Saltalamacchia': 2,
#  'Jason Castro': 6,
#  'Jason Coats': 1,
#  'Jason Heyward': 6,
#  'Jason Kipnis': 6,
#  'Javier Baez': 6,
#  'Javier Guerra': 1,
#  'Jay Bruce': 6,
#  'Jaycob Brugman': 2,
#  'Jean Segura': 6,
#  'Jed Lowrie': 6,
#  'Jedd Gyorko': 6,
#  'Jeff Mathis': 5,
#  'Jeff McNeil': 1,
#  'Jefry Marte': 5,
#  'Jeimer Candelario': 6,
#  'Jeremy Hazelbaker': 3,
#  'Jesmuel Valentin': 2,
#  'Jesse Winker': 6,
#  'Jesus Aguilar': 2,
#  'Jesus Sucre': 5,
#  'Jett Bandy': 5,
#  'Ji-Man Choi': 2,
#  'Jim Adduci': 2,
#  'Joc Pederson': 6,
#  'Joe Mauer': 6,
#  'Joe Panik': 6,
#  'Joey Gallo': 6,
#  'Joey Rickard': 5,
#  'Joey Terdoslavich': 1,
#  'Joey Votto': 6,
#  'Joey Wendle': 5,
#  'Johan Camargo': 5,
#  'John Andreoli': 1,
#  'John Hicks': 5,
#  'John Ryan Murphy': 4,
#  'Johnny Field': 1,
#  'Jon Jay': 5,
#  'Jonathan Davis': 1,
#  'Jonathan Lucroy': 6,
#  'Jonathan Schoop': 5,
#  'Jonathan Villar': 5,
#  'Jordan Luplow': 5,
#  'Jordan Patterson': 5,
#  'Jordy Mercer': 6,
#  'Jorge Alfaro': 6,
#  'Jorge Bonifacio': 5,
#  'Jorge Polanco': 6,
#  'Jorge Soler': 6,
#  'Jose Abreu': 6,
#  'Jose Altuve': 6,
#  'Jose Bautista': 3,
#  'Jose Fernandez': 1,
#  'Jose Iglesias': 5,
#  'Jose Lobaton': 4,
#  'Jose Martinez': 6,
#  'Jose Osuna': 5,
#  'Jose Peraza': 6,
#  'Jose Pirela': 6,
#  'Jose Ramirez': 6,
#  'Jose Reyes': 6,
#  'Jose Rondon': 2,
#  'Jose Trevino': 1,
#  'Josh Bell': 6,
#  'Josh Donaldson': 6,
#  'Josh Harrison': 6,
#  'Josh Phegley': 5,
#  'Josh Reddick': 6,
#  'Josh Thole': 1,
#  'Juan Centeno': 5,
#  'Juan Graterol': 2,
#  'Juan Lagares': 5,
#  'Jung Ho Kang': 1,
#  'Juniel Querecuto': 1,
#  'Jurickson Profar': 5,
#  'Justin Bour': 6,
#  'Justin Smoak': 6,
#  'Justin Turner': 6,
#  'Justin Upton': 6,
#  'Justin Williams': 2,
#  'Kaleb Cowart': 5,
#  'Kelby Tomlinson': 5,
#  'Kendrys Morales': 6,
#  'Kennys Vargas': 4,
#  'Keon Broxton': 5,
#  'Ketel Marte': 6,
#  'Kevan Smith': 5,
#  'Kevin Kaczmarski': 1,
#  'Kevin Kiermaier': 6,
#  'Kevin Kramer': 1,
#  'Kevin Newman': 1,
#  'Kevin Pillar': 6,
#  'Kevin Plawecki': 5,
#  'Khris Davis': 6,
#  'Kole Calhoun': 6,
#  'Kolten Wong': 6,
#  'Kris Bryant': 6,
#  'Kristopher Negron': 1,
#  'Kurt Suzuki': 5,
#  'Kyle Farmer': 5,
#  'Kyle Higashioka': 2,
#  'Kyle Schwarber': 6,
#  'Kyle Seager': 6,
#  'Kyle Tucker': 4,
#  'Lane Adams': 5,
#  'Leonys Martin': 5,
#  'Leury Garcia': 5,
#  'Lewis Brinson': 5,
#  'Logan Forsythe': 5,
#  'Logan Morrison': 5,
#  'Lonnie Chisenhall': 5,
#  'Lorenzo Cain': 6,
#  'Lourdes Gurriel Jr.': 1,
#  'Lucas Duda': 5,
#  'Luis Guillorme': 1,
#  'Luis Sardinas': 1,
#  'Luis Torrens': 2,
#  'Luis Urias': 5,
#  'Luke Maile': 5,
#  'Luke Voit': 6,
#  'Mac Williamson': 5,
#  'Magneuris Sierra': 5,
#  'Maikel Franco': 6,
#  'Mallex Smith': 5,
#  'Manny Machado': 6,
#  'Manny Pina': 5,
#  'Manuel Margot': 6,
#  'Marcell Ozuna': 6,
#  'Marco Hernandez': 2,
#  'Marcus Semien': 6,
#  'Mark Canha': 5,
#  'Mark Reynolds': 3,
#  'Mark Trumbo': 5,
#  'Mark Zagunis': 1,
#  'Martin Maldonado': 6,
#  'Martin Prado': 5,
#  'Marwin Gonzalez': 6,
#  'Mason Williams': 1,
#  'Matt Adams': 5,
#  'Matt Carpenter': 6,
#  'Matt Chapman': 6,
#  'Matt Davidson': 5,
#  'Matt den Dekker': 1,
#  'Matt Duffy': 5,
#  'Matt Holliday': 5,
#  'Matt Joyce': 6,
#  'Matt Kemp': 5,
#  'Matt McBride': 1,
#  'Matt Olson': 6,
#  'Matt Reynolds': 1,
#  'Matt Skole': 1,
#  'Matt Szczur': 5,
#  'Matt Wieters': 6,
#  'Max Kepler': 6,
#  'Max Moroff': 4,
#  'Max Muncy': 1,
#  'Max Stassi': 5,
#  'Meibrys Viloria': 1,
#  'Melky Cabrera': 4,
#  'Micah Johnson': 2,
#  'Michael A. Taylor': 6,
#  'Michael Brantley': 5,
#  'Michael Choice': 1,
#  'Michael Conforto': 6,
#  'Michael Hermosillo': 1,
#  'Michael Martinez': 1,
#  'Michael Perez': 1,
#  'Michael Reed': 1,
#  'Miguel Andujar': 6,
#  'Miguel Cabrera': 6,
#  'Miguel Gomez': 2,
#  'Miguel Rojas': 5,
#  'Miguel Sano': 6,
#  'Mike Freeman': 1,
#  'Mike Gerber': 5,
#  'Mike Moustakas': 6,
#  'Mike Napoli': 2,
#  'Mike Ohlman': 1,
#  'Mike Olt': 1,
#  'Mike Tauchman': 5,
#  'Mike Trout': 6,
#  'Mike Zunino': 6,
#  'Mikie Mahtook': 5,
#  'Mitch Garver': 6,
#  'Mitch Haniger': 6,
#  'Mitch Moreland': 6,
#  'Mitch Walding': 1,
#  'Moises Sierra': 1,
#  'Mookie Betts': 6,
#  'Myles Straw': 1,
#  'Nate Orf': 1,
#  'Neil Walker': 5,
#  'Nelson Cruz': 6,
#  'Nicholas Castellanos': 6,
#  'Nick Ahmed': 5,
#  'Nick Ciuffo': 1,
#  'Nick Franklin': 1,
#  'Nick Hundley': 5,
#  'Nick Markakis': 6,
#  'Nick Martini': 1,
#  'Nick Noonan': 1,
#  'Nick Williams': 6,
#  'Nicky Delmonico': 6,
#  'Niko Goodrum': 3,
#  'Noel Cuevas': 2,
#  'Nolan Arenado': 6,
#  'Nolan Fontana': 5,
#  'Nomar Mazara': 6,
#  'Odubel Herrera': 6,
#  'Omar Narvaez': 5,
#  'Orlando Arcia': 6,
#  'Orlando Calixte': 2,
#  'Oscar Hernandez': 1,
#  'Ozzie Albies': 6,
#  'Pablo Reyes': 1,
#  'Pablo Sandoval': 5,
#  'Pat Valaika': 5,
#  'Patrick Kivlehan': 2,
#  'Patrick Wisdom': 1,
#  'Paul DeJong': 6,
#  'Paul Goldschmidt': 6,
#  'Paulo Orlando': 5,
#  'Pedro Alvarez': 2,
#  'Pedro Florimon': 5,
#  'Pedro Severino': 2,
#  'Pete Kozma': 1,
#  'Peter Bourjos': 5,
#  "Peter O'Brien": 1,
#  'Phil Gosselin': 5,
#  'Phillip Ervin': 5,
#  'Phillip Evans': 1,
#  'Preston Tucker': 5,
#  'Quintin Berry': 1,
#  'Rafael Bautista': 2,
#  'Rafael Devers': 6,
#  'Rafael Ortega': 2,
#  'Raffy Lopez': 1,
#  'Raimel Tapia': 6,
#  'Rajai Davis': 5,
#  'Ramon Laureano': 1,
#  'Ramon Torres': 5,
#  'Randal Grichuk': 6,
#  'Raudy Read': 1,
#  'Reese McGuire': 1,
#  'Renato Nunez': 2,
#  'Rene Rivera': 5,
#  'Rey Fuentes': 2,
#  'Reynaldo Navarro': 1,
#  'Rhys Hoskins': 6,
#  'Richard Urena': 2,
#  'Richie Shaffer': 1,
#  'Rio Ruiz': 5,
#  'Rob Brantly': 1,
#  'Rob Refsnyder': 4,
#  'Rob Segedin': 5,
#  'Robbie Grossman': 6,
#  'Roberto Perez': 5,
#  'Robinson Cano': 6,
#  'Robinson Chirinos': 5,
#  'Rocky Gale': 2,
#  'Roman Quinn': 5,
#  'Ronald Acuna': 6,
#  'Ronald Guzman': 2,
#  'Ronald Torreyes': 6,
#  'Ronny Rodriguez': 1,
#  'Rosell Herrera': 1,
#  'Rougned Odor': 6,
#  'Rowdy Tellez': 1,
#  'Ruben Tejada': 1,
#  'Rusney Castillo': 2,
#  'Russell Martin': 6,
#  'Ryan Braun': 6,
#  'Ryan Cordell': 5,
#  'Ryan Flaherty': 4,
#  'Ryan Goins': 5,
#  'Ryan LaMarre': 4,
#  'Ryan Lavarnway': 1,
#  'Ryan McMahon': 6,
#  "Ryan O'Hearn": 2,
#  'Ryan Rua': 5,
#  'Ryan Zimmerman': 6,
#  'Ryder Jones': 2,
#  'Rymer Liriano': 1,
#  'Ryon Healy': 6,
#  'Salvador Perez': 6,
#  'Sam Travis': 2,
#  'Sandy Leon': 6,
#  'Scooter Gennett': 6,
#  'Scott Kingery': 4,
#  'Scott Schebler': 6,
#  'Shane Peterson': 1,
#  'Shane Robinson': 1,
#  "Shawn O'Malley": 1,
#  'Sherman Johnson': 1,
#  'Shin-Soo Choo': 6,
#  'Shohei Ohtani': 5,
#  'Socrates Brito': 5,
#  'Spencer Kieboom': 1,
#  'Starlin Castro': 6,
#  'Starling Marte': 6,
#  'Stephen Cardullo': 1,
#  'Stephen Piscotty': 6,
#  'Stephen Vogt': 5,
#  'Steve Lombardozzi': 1,
#  'Steve Pearce': 6,
#  'Steve Selsky': 1,
#  'Steve Wilkerson': 1,
#  'Steven Duggar': 5,
#  'Steven Souza Jr.': 5,
#  'Stuart Turner': 2,
#  'T.J. Rivera': 5,
#  'Taylor Davis': 1,
#  'Taylor Featherston': 2,
#  'Taylor Ward': 1,
#  'Teoscar Hernandez': 6,
#  'Terrance Gore': 2,
#  'Tim Anderson': 6,
#  'Tim Beckham': 5,
#  'Tim Federowicz': 2,
#  'Tim Locastro': 2,
#  'Todd Frazier': 6,
#  'Tom Murphy': 5,
#  'Tomas Nido': 2,
#  'Tomas Telis': 5,
#  'Tommy Joseph': 5,
#  'Tommy La Stella': 5,
#  'Tommy Pham': 6,
#  'Tony Kemp': 5,
#  'Tony Renda': 1,
#  'Tony Sanchez': 1,
#  'Tony Wolters': 5,
#  "Travis d'Arnaud": 6,
#  'Travis Jankowski': 5,
#  'Travis Shaw': 6,
#  'Travis Taijeron': 1,
#  'Trayce Thompson': 2,
#  'Trea Turner': 6,
#  'Trevor Brown': 1,
#  'Trevor Plouffe': 2,
#  'Trevor Story': 6,
#  'Trey Mancini': 6,
#  'Troy Tulowitzki': 6,
#  'Tucker Barnhart': 6,
#  'Tuffy Gosewisch': 2,
#  'Ty Kelly': 2,
#  'Tyler Austin': 5,
#  'Tyler Flowers': 6,
#  'Tyler Goeddel': 1,
#  'Tyler Ladendorf': 4,
#  'Tyler Naquin': 5,
#  "Tyler O'Neill": 2,
#  'Tyler Saladino': 5,
#  'Tyler Wade': 6,
#  'Tyler White': 5,
#  'Tzu-Wei Lin': 2,
#  'Victor Caratini': 5,
#  'Victor Martinez': 5,
#  'Victor Reyes': 5,
#  'Victor Robles': 6,
#  'Welington Castillo': 5,
#  'Whit Merrifield': 6,
#  'Wil Myers': 6,
#  'Wilfredo Tovar': 1,
#  'Will Middlebrooks': 2,
#  'Willians Astudillo': 1,
#  'Willie Calhoun': 5,
#  'Willson Contreras': 6,
#  'Willy Adames': 2,
#  'Wilmer Difo': 5,
#  'Wilmer Flores': 6,
#  'Wilson Ramos': 5,
#  'Xander Bogaerts': 6,
#  'Yadiel Rivera': 4,
#  'Yadier Molina': 6,
#  'Yairo Munoz': 4,
#  'Yan Gomes': 5,
#  'Yandy Diaz': 5,
#  'Yangervis Solarte': 6,
#  'Yasiel Puig': 6,
#  'Yasmani Grandal': 6,
#  'Yasmany Tomas': 5,
#  'Yefri Perez': 1,
#  'Yoan Moncada': 6,
#  'Yoenis Cespedes': 6,
#  'Yolmer Sanchez': 6,
#  'Yonder Alonso': 6,
#  'Yuli Gurriel': 6,
#  'Zach Vincej': 2,
#  'Zack Cozart': 6,
#  'Zack Granite': 6}

# %% [markdown]
# ### Select names with 3+ projections

# %%
# create a list to store the names of players without 3+ projections. Add those players to that list, and remove those players from the original list of names
notEnoughEntries = []
for name in nameCounter:
    if nameCounter[name] < 3:
        notEnoughEntries.append(name)
        names.remove(name)
notEnoughEntries
# Out:
# ['Abiatal Avelino',
#  'Adam Moore',
#  'Adam Rosales',
#  'Adolis Garcia',
#  'Adrian Sanchez',
#  'Alberto Rosario',
#  'Alen Hanson',
#  'Alex Blandino',
#  'Alex Dickerson',
#  'Alex Mejia',
#  'Alfredo Gonzalez',
#  'Ali Solis',
#  'Allen Craig',
#  'Andres Blanco',
#  'Andy Wilkins',
#  'Anthony Recker',
#  'Aramis Garcia',
#  'Arismendy Alcantara',
#  'Aristides Aquino',
#  'Audry Perez',
#  'Austin Dean',
#  'Austin Slater',
#  'Austin Wynns',
#  'Beau Taylor',
#  'Billy Burns',
#  'Billy McKinney',
#  'Blake Trahan',
#  'Bobby Wilson',
#  'Brandon Barnes',
#  'Brandon Lowe',
#  'Brandon Snyder',
#  'Brett Eibner',
#  'Brett Nicholas',
#  'Brett Phillips',
#  'Breyvic Valera',
#  'Brock Stassi',
#  'Bryan Holaday',
#  'Bryce Brentz',
#  'Cam Perkins',
#  'Cameron Rupp',
#  'Carlos Moncrief',
#  'Carlos Perez',
#  'Carlos Rivero',
#  'Cedric Mullins II',
#  'Cesar Puello',
#  'Chad Huffman',
#  'Charlie Tilson',
#  "Chase d'Arnaud",
#  'Chris Coghlan',
#  'Chris Dominguez',
#  'Chris Herrmann',
#  'Chris Marrero',
#  'Chris Shaw',
#  'Chris Stewart',
#  'Christian Colon',
#  'Christian Walker',
#  'Christin Stewart',
#  'Christopher Bostick',
#  'Cody Asche',
#  'Cody Decker',
#  'Colin Walsh',
#  'Collin Cowgill',
#  'Corban Joseph',
#  'Cristhian Adames',
#  'Curt Casali',
#  'D.J. Stewart',
#  'Dalton Pompey',
#  'Dan Butler',
#  'Daniel Castro',
#  'Daniel Muno',
#  'Daniel Nava',
#  'Daniel Palka',
#  'Danny Espinosa',
#  'Danny Ortiz',
#  'Danny Santana',
#  'Darnell Sweeney',
#  'Darwin Barney',
#  'David Bote',
#  'David Fletcher',
#  'David Freitas',
#  'David Wright',
#  'Desmond Jennings',
#  'Destin Hood',
#  'Dilson Herrera',
#  'Donovan Solano',
#  'Dustin Ackley',
#  'Dustin Garneau',
#  'Dustin Peterson',
#  'Dusty Coleman',
#  'Dwight Smith Jr.',
#  'Edmundo Sosa',
#  'Emilio Bonifacio',
#  'Eric Haase',
#  'Eric Young Jr.',
#  'Erick Aybar',
#  'Erik Gonzalez',
#  'Erik Kratz',
#  'Eury Perez',
#  'Everth Cabrera',
#  'Franmil Reyes',
#  'Gabriel Guerrero',
#  'Garrett Hampson',
#  'Gordon Beckham',
#  'Grayson Greiner',
#  'Greg Allen',
#  'Gregorio Petit',
#  'Henry Urrutia',
#  'Hernan Iribarren',
#  'Ildemaro Vargas',
#  'Irving Falu',
#  'Isaac Galloway',
#  'Isiah Kiner-Falefa',
#  'Ivan De Jesus',
#  'J.B. Shuck',
#  'Jabari Blash',
#  'Jace Peterson',
#  'Jack Reinheimer',
#  'Jackson Williams',
#  'Jacob Hannemann',
#  'Jacob Nottingham',
#  'Jake Elmore',
#  'Jarrod Saltalamacchia',
#  'Jason Coats',
#  'Javier Guerra',
#  'Jaycob Brugman',
#  'Jeff McNeil',
#  'Jesmuel Valentin',
#  'Jesus Aguilar',
#  'Ji-Man Choi',
#  'Jim Adduci',
#  'Joey Terdoslavich',
#  'John Andreoli',
#  'Johnny Field',
#  'Jonathan Davis',
#  'Jose Fernandez',
#  'Jose Rondon',
#  'Jose Trevino',
#  'Josh Thole',
#  'Juan Graterol',
#  'Jung Ho Kang',
#  'Juniel Querecuto',
#  'Justin Williams',
#  'Kevin Kaczmarski',
#  'Kevin Kramer',
#  'Kevin Newman',
#  'Kristopher Negron',
#  'Kyle Higashioka',
#  'Lourdes Gurriel Jr.',
#  'Luis Guillorme',
#  'Luis Sardinas',
#  'Luis Torrens',
#  'Marco Hernandez',
#  'Mark Zagunis',
#  'Mason Williams',
#  'Matt den Dekker',
#  'Matt McBride',
#  'Matt Reynolds',
#  'Matt Skole',
#  'Max Muncy',
#  'Meibrys Viloria',
#  'Micah Johnson',
#  'Michael Choice',
#  'Michael Hermosillo',
#  'Michael Martinez',
#  'Michael Perez',
#  'Michael Reed',
#  'Miguel Gomez',
#  'Mike Freeman',
#  'Mike Napoli',
#  'Mike Ohlman',
#  'Mike Olt',
#  'Mitch Walding',
#  'Moises Sierra',
#  'Myles Straw',
#  'Nate Orf',
#  'Nick Ciuffo',
#  'Nick Franklin',
#  'Nick Martini',
#  'Nick Noonan',
#  'Noel Cuevas',
#  'Orlando Calixte',
#  'Oscar Hernandez',
#  'Pablo Reyes',
#  'Patrick Kivlehan',
#  'Patrick Wisdom',
#  'Pedro Alvarez',
#  'Pedro Severino',
#  'Pete Kozma',
#  "Peter O'Brien",
#  'Phillip Evans',
#  'Quintin Berry',
#  'Rafael Bautista',
#  'Rafael Ortega',
#  'Raffy Lopez',
#  'Ramon Laureano',
#  'Raudy Read',
#  'Reese McGuire',
#  'Renato Nunez',
#  'Rey Fuentes',
#  'Reynaldo Navarro',
#  'Richard Urena',
#  'Richie Shaffer',
#  'Rob Brantly',
#  'Rocky Gale',
#  'Ronald Guzman',
#  'Ronny Rodriguez',
#  'Rosell Herrera',
#  'Rowdy Tellez',
#  'Ruben Tejada',
#  'Rusney Castillo',
#  'Ryan Lavarnway',
#  "Ryan O'Hearn",
#  'Ryder Jones',
#  'Rymer Liriano',
#  'Sam Travis',
#  'Shane Peterson',
#  'Shane Robinson',
#  "Shawn O'Malley",
#  'Sherman Johnson',
#  'Spencer Kieboom',
#  'Stephen Cardullo',
#  'Steve Lombardozzi',
#  'Steve Selsky',
#  'Steve Wilkerson',
#  'Stuart Turner',
#  'Taylor Davis',
#  'Taylor Featherston',
#  'Taylor Ward',
#  'Terrance Gore',
#  'Tim Federowicz',
#  'Tim Locastro',
#  'Tomas Nido',
#  'Tony Renda',
#  'Tony Sanchez',
#  'Travis Taijeron',
#  'Trayce Thompson',
#  'Trevor Brown',
#  'Trevor Plouffe',
#  'Tuffy Gosewisch',
#  'Ty Kelly',
#  'Tyler Goeddel',
#  "Tyler O'Neill",
#  'Tzu-Wei Lin',
#  'Wilfredo Tovar',
#  'Will Middlebrooks',
#  'Willians Astudillo',
#  'Willy Adames',
#  'Yefri Perez',
#  'Zach Vincej']

# %%
names
# Out:
# ['A.J. Ellis',
#  'A.J. Pollock',
#  'A.J. Reed',
#  'Aaron Altherr',
#  'Aaron Hicks',
#  'Aaron Judge',
#  'Adalberto Mondesi',
#  'Adam Duvall',
#  'Adam Eaton',
#  'Adam Engel',
#  'Adam Frazier',
#  'Adam Jones',
#  'Addison Russell',
#  'Adeiny Hechavarria',
#  'Adrian Beltre',
#  'Albert Almora Jr.',
#  'Albert Pujols',
#  'Alcides Escobar',
#  'Aledmys Diaz',
#  'Alex Avila',
#  'Alex Bregman',
#  'Alex Gordon',
#  'Alex Verdugo',
#  'Allen Cordoba',
#  'Amed Rosario',
#  'Andrelton Simmons',
#  'Andrew Benintendi',
#  'Andrew Knapp',
#  'Andrew McCutchen',
#  'Andrew Romine',
#  'Andrew Stevenson',
#  'Andrew Susac',
#  'Andrew Toles',
#  'Anthony Alford',
#  'Anthony Rendon',
#  'Anthony Rizzo',
#  'Anthony Santander',
#  'Asdrubal Cabrera',
#  'Austin Barnes',
#  'Austin Hays',
#  'Austin Hedges',
#  'Austin Jackson',
#  'Austin Meadows',
#  'Austin Romine',
#  'Avisail Garcia',
#  'Ben Gamel',
#  'Ben Zobrist',
#  'Billy Hamilton',
#  'Blake Swihart',
#  'Boog Powell',
#  'Bradley Zimmer',
#  'Brandon Belt',
#  'Brandon Crawford',
#  'Brandon Dixon',
#  'Brandon Drury',
#  'Brandon Guyer',
#  'Brandon Nimmo',
#  'Brandon Phillips',
#  'Braxton Lee',
#  'Brett Gardner',
#  'Brian Anderson',
#  'Brian Dozier',
#  'Brian Goodwin',
#  'Brian McCann',
#  'Brock Holt',
#  'Bruce Maxwell',
#  'Bryce Harper',
#  'Buster Posey',
#  'Byron Buxton',
#  'C.J. Cron',
#  'Caleb Joseph',
#  'Cam Gallagher',
#  'Cameron Maybin',
#  'Carlos Asuaje',
#  'Carlos Correa',
#  'Carlos Gomez',
#  'Carlos Gonzalez',
#  'Carlos Santana',
#  'Carlos Tocci',
#  'Carson Kelly',
#  'Cesar Hernandez',
#  'Chad Pinder',
#  'Chad Wallach',
#  'Chance Sisco',
#  'Charlie Blackmon',
#  'Charlie Culberson',
#  'Chase Utley',
#  'Cheslor Cuthbert',
#  'Chris Davis',
#  'Chris Gimenez',
#  'Chris Iannetta',
#  'Chris Owings',
#  'Chris Taylor',
#  'Chris Young',
#  'Christian Arroyo',
#  'Christian Vazquez',
#  'Christian Villanueva',
#  'Christian Yelich',
#  'Cliff Pennington',
#  'Clint Frazier',
#  'Cody Bellinger',
#  'Colby Rasmus',
#  'Colin Moran',
#  'Corey Dickerson',
#  'Corey Seager',
#  'Cory Spangenberg',
#  'Curtis Granderson',
#  'Dan Vogelbach',
#  'Daniel Descalso',
#  'Daniel Murphy',
#  'Daniel Robertson',
#  'Danny Jansen',
#  'Dansby Swanson',
#  'David Dahl',
#  'David Freese',
#  'David Peralta',
#  'Dawel Lugo',
#  'Dee Gordon',
#  'Delino DeShields',
#  'Denard Span',
#  'Derek Dietrich',
#  'Derek Fisher',
#  'Deven Marrero',
#  'Devin Mesoraco',
#  'Devon Travis',
#  'Dexter Fowler',
#  'Didi Gregorius',
#  'Dixon Machado',
#  'DJ LeMahieu',
#  'Domingo Santana',
#  'Dominic Smith',
#  'Drew Butera',
#  'Drew Robinson',
#  'Dustin Fowler',
#  'Dustin Pedroia',
#  'Dylan Cozens',
#  'Eddie Rosario',
#  'Eduardo Escobar',
#  'Eduardo Nunez',
#  'Edwin Encarnacion',
#  'Ehire Adrianza',
#  'Elias Diaz',
#  'Elvis Andrus',
#  'Ender Inciarte',
#  'Engelb Vielma',
#  'Enrique Hernandez',
#  'Eric Hosmer',
#  'Eric Thames',
#  'Eugenio Suarez',
#  'Evan Gattis',
#  'Evan Longoria',
#  'Ezequiel Carrera',
#  'Franchy Cordero',
#  'Francisco Cervelli',
#  'Francisco Lindor',
#  'Francisco Mejia',
#  'Francisco Pena',
#  'Franklin Barreto',
#  'Freddie Freeman',
#  'Freddy Galvis',
#  'Garrett Cooper',
#  'Gary Sanchez',
#  'Gavin Cecchini',
#  'George Springer',
#  'Gerardo Parra',
#  'Giancarlo Stanton',
#  'Gift Ngoepe',
#  'Giovanny Urshela',
#  'Gleyber Torres',
#  'Gorkys Hernandez',
#  'Greg Bird',
#  'Greg Garcia',
#  'Gregor Blanco',
#  'Gregory Polanco',
#  'Guillermo Heredia',
#  'Hanser Alberto',
#  'Harrison Bader',
#  'Hernan Perez',
#  'Howie Kendrick',
#  'Hunter Dozier',
#  'Hunter Pence',
#  'Hunter Renfroe',
#  'Ian Desmond',
#  'Ian Happ',
#  'Ian Kinsler',
#  'J.D. Davis',
#  'J.D. Martinez',
#  'J.P. Crawford',
#  'J.T. Realmuto',
#  'J.T. Riddle',
#  'Jackie Bradley Jr.',
#  'Jacob Stallings',
#  'Jacoby Ellsbury',
#  'JaCoby Jones',
#  'Jake Bauers',
#  'Jake Cave',
#  'Jake Lamb',
#  'Jake Marisnick',
#  'Jake Smolinski',
#  'James McCann',
#  'Jarrod Dyson',
#  'Jason Castro',
#  'Jason Heyward',
#  'Jason Kipnis',
#  'Javier Baez',
#  'Jay Bruce',
#  'Jean Segura',
#  'Jed Lowrie',
#  'Jedd Gyorko',
#  'Jeff Mathis',
#  'Jefry Marte',
#  'Jeimer Candelario',
#  'Jeremy Hazelbaker',
#  'Jesse Winker',
#  'Jesus Sucre',
#  'Jett Bandy',
#  'Joc Pederson',
#  'Joe Mauer',
#  'Joe Panik',
#  'Joey Gallo',
#  'Joey Rickard',
#  'Joey Votto',
#  'Joey Wendle',
#  'Johan Camargo',
#  'John Hicks',
#  'John Ryan Murphy',
#  'Jon Jay',
#  'Jonathan Lucroy',
#  'Jonathan Schoop',
#  'Jonathan Villar',
#  'Jordan Luplow',
#  'Jordan Patterson',
#  'Jordy Mercer',
#  'Jorge Alfaro',
#  'Jorge Bonifacio',
#  'Jorge Polanco',
#  'Jorge Soler',
#  'Jose Abreu',
#  'Jose Altuve',
#  'Jose Bautista',
#  'Jose Iglesias',
#  'Jose Lobaton',
#  'Jose Martinez',
#  'Jose Osuna',
#  'Jose Peraza',
#  'Jose Pirela',
#  'Jose Ramirez',
#  'Jose Reyes',
#  'Josh Bell',
#  'Josh Donaldson',
#  'Josh Harrison',
#  'Josh Phegley',
#  'Josh Reddick',
#  'Juan Centeno',
#  'Juan Lagares',
#  'Jurickson Profar',
#  'Justin Bour',
#  'Justin Smoak',
#  'Justin Turner',
#  'Justin Upton',
#  'Kaleb Cowart',
#  'Kelby Tomlinson',
#  'Kendrys Morales',
#  'Kennys Vargas',
#  'Keon Broxton',
#  'Ketel Marte',
#  'Kevan Smith',
#  'Kevin Kiermaier',
#  'Kevin Pillar',
#  'Kevin Plawecki',
#  'Khris Davis',
#  'Kole Calhoun',
#  'Kolten Wong',
#  'Kris Bryant',
#  'Kurt Suzuki',
#  'Kyle Farmer',
#  'Kyle Schwarber',
#  'Kyle Seager',
#  'Kyle Tucker',
#  'Lane Adams',
#  'Leonys Martin',
#  'Leury Garcia',
#  'Lewis Brinson',
#  'Logan Forsythe',
#  'Logan Morrison',
#  'Lonnie Chisenhall',
#  'Lorenzo Cain',
#  'Lucas Duda',
#  'Luis Urias',
#  'Luke Maile',
#  'Luke Voit',
#  'Mac Williamson',
#  'Magneuris Sierra',
#  'Maikel Franco',
#  'Mallex Smith',
#  'Manny Machado',
#  'Manny Pina',
#  'Manuel Margot',
#  'Marcell Ozuna',
#  'Marcus Semien',
#  'Mark Canha',
#  'Mark Reynolds',
#  'Mark Trumbo',
#  'Martin Maldonado',
#  'Martin Prado',
#  'Marwin Gonzalez',
#  'Matt Adams',
#  'Matt Carpenter',
#  'Matt Chapman',
#  'Matt Davidson',
#  'Matt Duffy',
#  'Matt Holliday',
#  'Matt Joyce',
#  'Matt Kemp',
#  'Matt Olson',
#  'Matt Szczur',
#  'Matt Wieters',
#  'Max Kepler',
#  'Max Moroff',
#  'Max Stassi',
#  'Melky Cabrera',
#  'Michael A. Taylor',
#  'Michael Brantley',
#  'Michael Conforto',
#  'Miguel Andujar',
#  'Miguel Cabrera',
#  'Miguel Rojas',
#  'Miguel Sano',
#  'Mike Gerber',
#  'Mike Moustakas',
#  'Mike Tauchman',
#  'Mike Trout',
#  'Mike Zunino',
#  'Mikie Mahtook',
#  'Mitch Garver',
#  'Mitch Haniger',
#  'Mitch Moreland',
#  'Mookie Betts',
#  'Neil Walker',
#  'Nelson Cruz',
#  'Nicholas Castellanos',
#  'Nick Ahmed',
#  'Nick Hundley',
#  'Nick Markakis',
#  'Nick Williams',
#  'Nicky Delmonico',
#  'Niko Goodrum',
#  'Nolan Arenado',
#  'Nolan Fontana',
#  'Nomar Mazara',
#  'Odubel Herrera',
#  'Omar Narvaez',
#  'Orlando Arcia',
#  'Ozzie Albies',
#  'Pablo Sandoval',
#  'Pat Valaika',
#  'Paul DeJong',
#  'Paul Goldschmidt',
#  'Paulo Orlando',
#  'Pedro Florimon',
#  'Peter Bourjos',
#  'Phil Gosselin',
#  'Phillip Ervin',
#  'Preston Tucker',
#  'Rafael Devers',
#  'Raimel Tapia',
#  'Rajai Davis',
#  'Ramon Torres',
#  'Randal Grichuk',
#  'Rene Rivera',
#  'Rhys Hoskins',
#  'Rio Ruiz',
#  'Rob Refsnyder',
#  'Rob Segedin',
#  'Robbie Grossman',
#  'Roberto Perez',
#  'Robinson Cano',
#  'Robinson Chirinos',
#  'Roman Quinn',
#  'Ronald Acuna',
#  'Ronald Torreyes',
#  'Rougned Odor',
#  'Russell Martin',
#  'Ryan Braun',
#  'Ryan Cordell',
#  'Ryan Flaherty',
#  'Ryan Goins',
#  'Ryan LaMarre',
#  'Ryan McMahon',
#  'Ryan Rua',
#  'Ryan Zimmerman',
#  'Ryon Healy',
#  'Salvador Perez',
#  'Sandy Leon',
#  'Scooter Gennett',
#  'Scott Kingery',
#  'Scott Schebler',
#  'Shin-Soo Choo',
#  'Shohei Ohtani',
#  'Socrates Brito',
#  'Starlin Castro',
#  'Starling Marte',
#  'Stephen Piscotty',
#  'Stephen Vogt',
#  'Steve Pearce',
#  'Steven Duggar',
#  'Steven Souza Jr.',
#  'T.J. Rivera',
#  'Teoscar Hernandez',
#  'Tim Anderson',
#  'Tim Beckham',
#  'Todd Frazier',
#  'Tom Murphy',
#  'Tomas Telis',
#  'Tommy Joseph',
#  'Tommy La Stella',
#  'Tommy Pham',
#  'Tony Kemp',
#  'Tony Wolters',
#  "Travis d'Arnaud",
#  'Travis Jankowski',
#  'Travis Shaw',
#  'Trea Turner',
#  'Trevor Story',
#  'Trey Mancini',
#  'Troy Tulowitzki',
#  'Tucker Barnhart',
#  'Tyler Austin',
#  'Tyler Flowers',
#  'Tyler Ladendorf',
#  'Tyler Naquin',
#  'Tyler Saladino',
#  'Tyler Wade',
#  'Tyler White',
#  'Victor Caratini',
#  'Victor Martinez',
#  'Victor Reyes',
#  'Victor Robles',
#  'Welington Castillo',
#  'Whit Merrifield',
#  'Wil Myers',
#  'Willie Calhoun',
#  'Willson Contreras',
#  'Wilmer Difo',
#  'Wilmer Flores',
#  'Wilson Ramos',
#  'Xander Bogaerts',
#  'Yadiel Rivera',
#  'Yadier Molina',
#  'Yairo Munoz',
#  'Yan Gomes',
#  'Yandy Diaz',
#  'Yangervis Solarte',
#  'Yasiel Puig',
#  'Yasmani Grandal',
#  'Yasmany Tomas',
#  'Yoan Moncada',
#  'Yoenis Cespedes',
#  'Yolmer Sanchez',
#  'Yonder Alonso',
#  'Yuli Gurriel',
#  'Zack Cozart',
#  'Zack Granite']

# %% [markdown]
# ### Remove projections of players that have less than 3 different projections

# %%
for name in notEnoughEntries:
    projections = projections[projections.Name != name]

# %%
projections
# Out:
#               Name          Team          Type    G   PA   AB    H  2B  3B  \
# 0       A.J. Ellis        Padres           ATC   32  114   99   22   4   0
# 1       A.J. Ellis        Padres       The Bat   40  158  138   33   6   1
# 2       A.J. Ellis        Padres  Depth Charts   38  160  140   31   6   0
# 3       A.J. Ellis        Padres       Steamer   33  129  112   26   5   0
# 4       A.J. Ellis        Padres          ZiPS   50  155  137   29   6   0
# 5     A.J. Pollock  Diamondbacks           ATC  141  586  533  150  36   7
# 6     A.J. Pollock  Diamondbacks       The Bat  143  619  557  155  36   5
# 7     A.J. Pollock  Diamondbacks  Depth Charts  147  616  557  160  38   6
# 8     A.J. Pollock  Diamondbacks     Fangraphs  130  591  534  152  35   5
# 9     A.J. Pollock  Diamondbacks       Steamer  124  559  500  141  33   5
# 10    A.J. Pollock  Diamondbacks          ZiPS  125  510  466  136  33   6
# 11       A.J. Reed        Astros           ATC   46  181  160   38   8   0
# ...            ...           ...           ...  ...  ...  ...  ...  ..  ..
# 2851   Zack Cozart        Angels           ATC  132  532  475  127  26   4
# 2852   Zack Cozart        Angels       The Bat  138  591  527  137  25   2
# 2853   Zack Cozart        Angels  Depth Charts  142  595  535  137  25   5
# 2854   Zack Cozart        Angels     Fangraphs  134  549  489  131  27   4
# 2855   Zack Cozart        Angels       Steamer  122  507  455  116  21   4
# 2856   Zack Cozart        Angels          ZiPS  116  467  421  108  20   4
# 2857  Zack Granite         Twins           ATC   56  210  189   52   9   1
# 2858  Zack Granite         Twins       The Bat   11   49   44   12   2   0
# 2859  Zack Granite         Twins  Depth Charts   12   49   45   12   2   0
# 2860  Zack Granite         Twins     Fangraphs   71  289  257   66   7   3
# 2861  Zack Granite         Twins       Steamer   27  107   98   27   4   1
# 2862  Zack Granite         Twins          ZiPS  133  587  535  138  18   6
#
#       HR   R  RBI  BB  SO  SB  CS    AVG    OBP    SLG    OPS   wOBA    ADP  \
# 0      3   9   10  12  20   0   0  0.218  0.312  0.349  0.661  0.292  999.0
# 1      4  16   16  16  30   1   0  0.237  0.320  0.372  0.692  0.301  999.0
# 2      4  15   17  15  30   1   0  0.223  0.309  0.361  0.670  0.293  999.0
# 3      4  13   13  14  25   1   1  0.234  0.323  0.379  0.702  0.307  999.0
# 4      4  13   16  12  28   0   0  0.212  0.294  0.343  0.637  0.279  999.0
# 5     16  88   60  45  86  28   7  0.281  0.341  0.463  0.803  0.342   68.2
# 6     18  83   76  53  92  22   7  0.278  0.344  0.456  0.801  0.342   68.2
# 7     19  92   68  48  92  26   9  0.287  0.347  0.480  0.827  0.351   68.2
# 8     16  96   64  49  89  26   5  0.285  0.347  0.459  0.806  0.344   68.2
# 9     17  80   61  47  85  22   9  0.282  0.346  0.469  0.815  0.347   68.2
# 10    16  80   57  37  75  22   6  0.292  0.347  0.491  0.838  0.355   68.2
# 11     7  22   24  18  51   0   0  0.237  0.318  0.414  0.732  0.316  630.5
# ...   ..  ..  ...  ..  ..  ..  ..    ...    ...    ...    ...    ...    ...
# 2851  20  73   62  50  81   4   1  0.268  0.339  0.463  0.802  0.342  222.2
# 2852  23  75   72  54  92   4   1  0.260  0.331  0.449  0.780  0.333  222.2
# 2853  18  73   68  50  94   4   2  0.256  0.322  0.424  0.746  0.319  222.2
# 2854  20  69   74  52  82   4   1  0.268  0.339  0.462  0.801  0.340  222.2
# 2855  16  60   61  43  80   3   2  0.255  0.322  0.425  0.747  0.320  222.2
# 2856  14  59   50  39  74   3   1  0.257  0.322  0.423  0.745  0.318  222.2
# 2857   3  25   20  16  25   8   3  0.275  0.334  0.382  0.716  0.312  643.2
# 2858   1   6    4   4   6   2   1  0.270  0.325  0.366  0.691  0.302  643.2
# 2859   0   5    4   3   6   3   1  0.270  0.322  0.361  0.683  0.299  643.2
# 2860   2  21   23  28  28   9   2  0.257  0.332  0.331  0.663  0.296  643.2
# 2861   1  12   11   8  13   5   3  0.282  0.335  0.386  0.721  0.313  643.2
# 2862   4  64   44  38  76  38  14  0.258  0.309  0.336  0.646  0.284  643.2
#
#       playerid
# 0         5677
# 1         5677
# 2         5677
# 3         5677
# 4         5677
# 5         9256
# 6         9256
# 7         9256
# 8         9256
# 9         9256
# 10        9256
# 11       16246
# ...        ...
# 2851      2616
# 2852      2616
# 2853      2616
# 2854      2616
# 2855      2616
# 2856      2616
# 2857     15343
# 2858     15343
# 2859     15343
# 2860     15343
# 2861     15343
# 2862     15343
#
# [2529 rows x 23 columns]

# %% [markdown]
# ### Create an average of all projections for each player and add to table

# %%
cols = projections.columns.values.tolist()

for name in names:
    currentPlayer = projections.loc[projections['Name'] == name]
    # set name, team, projection type
    playerName = currentPlayer["Name"].values.tolist()[0]
    team = currentPlayer["Team"].values.tolist()[0]
    projectionType = "A-Average" # the name 'A-Average' is solely for sorting purposes- want the average projections to appear first later on
    # calculate average games
    g = currentPlayer["G"].values.tolist()
    total = 0
    for i in g:
        total = total + i
    average = total / len(g)
    g = int(round(average))
    # calculate average plate appearances
    pa = currentPlayer["PA"].values.tolist()
    total = 0
    for i in pa:
        total = total + i
    average = total / len(pa)
    pa = int(round(average))
    # calculate average at bats
    ab = currentPlayer["AB"].values.tolist()
    total = 0
    for i in ab:
        total = total + i
    average = total / len(ab)
    ab = int(round(average))
    # calculate average hits
    h = currentPlayer["H"].values.tolist()
    total = 0
    for i in h:
        total = total + i
    average = total / len(h)
    h = int(round(average))
    # calculate average doubles
    doubles = currentPlayer["2B"].values.tolist()
    total = 0
    for i in doubles:
        total = total + i
    average = total / len(doubles)
    doubles = int(round(average))
    # calculate average triples
    triples = currentPlayer["3B"].values.tolist()
    total = 0
    for i in triples:
        total = total + i
    average = total / len(triples)
    triples = int(round(average))
    # calculate average home runs
    hr = currentPlayer["HR"].values.tolist()
    total = 0
    for i in hr:
        total = total + i
    average = total / len(hr)
    hr = int(round(average))
    # calculate average runs
    r = currentPlayer["R"].values.tolist()
    total = 0
    for i in r:
        total = total + i
    average = total / len(r)
    r = int(round(average))
    # calculate average runs batted in
    rbi = currentPlayer["RBI"].values.tolist()
    total = 0
    for i in rbi:
        total = total + i
    average = total / len(rbi)
    rbi = int(round(average))
    # calculate average walks
    bb = currentPlayer["BB"].values.tolist()
    total = 0
    for i in bb:
        total = total + i
    average = total / len(bb)
    bb = int(round(average))
    # calculate average strikeouts
    so = currentPlayer["SO"].values.tolist()
    total = 0
    for i in so:
        total = total + i
    average = total / len(so)
    so = int(round(average))
    # calculate average steals
    sb = currentPlayer["SB"].values.tolist()
    total = 0
    for i in sb:
        total = total + i
    average = total / len(sb)
    sb = int(round(average))
    # calculate average caught stealing
    cs = currentPlayer["CS"].values.tolist()
    total = 0
    for i in cs:
        total = total + i
    average = total / len(cs)
    cs = int(round(average))
    # calculate average batting average
    avg = currentPlayer["AVG"].values.tolist()
    total = 0
    for i in avg:
        total = total + i
    average = total / len(avg)
    avg = round(average, 3)
    # calculate average on base percentage
    obp = currentPlayer["OBP"].values.tolist()
    total = 0
    for i in obp:
        total = total + i
    average = total / len(obp)
    obp = round(average, 3)
    # calculate average slugging percentage
    slg = currentPlayer["SLG"].values.tolist()
    total = 0
    for i in slg:
        total = total + i
    average = total / len(slg)
    slg = round(average, 3)
    # calculate average on base plus slugging
    ops = currentPlayer["OPS"].values.tolist()
    total = 0
    for i in ops:
        total = total + i
    average = total / len(ops)
    ops = round(average, 3)
    # calculate average weighted on base average
    woba = currentPlayer["wOBA"].values.tolist()
    total = 0
    for i in woba:
        total = total + i
    average = total / len(woba)
    woba = round(average, 3)
    #set average draft position, player ID
    adp = currentPlayer["ADP"].values.tolist()[0]
    playerID = currentPlayer["playerid"].values.tolist()[0]
    
    #create dataframe of new entry with average projections
    newEntry = [playerName, team, projectionType, g, pa, ab, h, doubles, triples, hr, r, rbi, bb, so, sb, cs, avg, obp, slg, ops, woba, adp, playerID]
    newEntry = pd.DataFrame([newEntry], columns=cols)
    
    #append new entry to projections
    projections = projections.append(newEntry)

# %% [markdown]
# ### Sort the table by name, team, and projection type for easier comparisons

# %%
 projections = projections.sort_values(by=["Name", "Team", "Type"])

# %%
projections
# Out:
#               Name          Team          Type    G   PA   AB    H  2B  3B  \
# 0       A.J. Ellis        Padres     A-Average   39  143  125   28   5   0
# 0       A.J. Ellis        Padres           ATC   32  114   99   22   4   0
# 2       A.J. Ellis        Padres  Depth Charts   38  160  140   31   6   0
# 3       A.J. Ellis        Padres       Steamer   33  129  112   26   5   0
# 1       A.J. Ellis        Padres       The Bat   40  158  138   33   6   1
# 4       A.J. Ellis        Padres          ZiPS   50  155  137   29   6   0
# 0     A.J. Pollock  Diamondbacks     A-Average  135  580  524  149  35   6
# 5     A.J. Pollock  Diamondbacks           ATC  141  586  533  150  36   7
# 7     A.J. Pollock  Diamondbacks  Depth Charts  147  616  557  160  38   6
# 8     A.J. Pollock  Diamondbacks     Fangraphs  130  591  534  152  35   5
# 9     A.J. Pollock  Diamondbacks       Steamer  124  559  500  141  33   5
# 6     A.J. Pollock  Diamondbacks       The Bat  143  619  557  155  36   5
# ...            ...           ...           ...  ...  ...  ...  ...  ..  ..
# 2853   Zack Cozart        Angels  Depth Charts  142  595  535  137  25   5
# 2854   Zack Cozart        Angels     Fangraphs  134  549  489  131  27   4
# 2855   Zack Cozart        Angels       Steamer  122  507  455  116  21   4
# 2852   Zack Cozart        Angels       The Bat  138  591  527  137  25   2
# 2856   Zack Cozart        Angels          ZiPS  116  467  421  108  20   4
# 0     Zack Granite         Twins     A-Average   52  215  195   51   7   2
# 2857  Zack Granite         Twins           ATC   56  210  189   52   9   1
# 2859  Zack Granite         Twins  Depth Charts   12   49   45   12   2   0
# 2860  Zack Granite         Twins     Fangraphs   71  289  257   66   7   3
# 2861  Zack Granite         Twins       Steamer   27  107   98   27   4   1
# 2858  Zack Granite         Twins       The Bat   11   49   44   12   2   0
# 2862  Zack Granite         Twins          ZiPS  133  587  535  138  18   6
#
#       HR   R  RBI  BB  SO  SB  CS    AVG    OBP    SLG    OPS   wOBA    ADP  \
# 0      4  13   14  14  27   1   0  0.225  0.312  0.361  0.672  0.294  999.0
# 0      3   9   10  12  20   0   0  0.218  0.312  0.349  0.661  0.292  999.0
# 2      4  15   17  15  30   1   0  0.223  0.309  0.361  0.670  0.293  999.0
# 3      4  13   13  14  25   1   1  0.234  0.323  0.379  0.702  0.307  999.0
# 1      4  16   16  16  30   1   0  0.237  0.320  0.372  0.692  0.301  999.0
# 4      4  13   16  12  28   0   0  0.212  0.294  0.343  0.637  0.279  999.0
# 0     17  86   64  46  86  24   7  0.284  0.345  0.470  0.815  0.347   68.2
# 5     16  88   60  45  86  28   7  0.281  0.341  0.463  0.803  0.342   68.2
# 7     19  92   68  48  92  26   9  0.287  0.347  0.480  0.827  0.351   68.2
# 8     16  96   64  49  89  26   5  0.285  0.347  0.459  0.806  0.344   68.2
# 9     17  80   61  47  85  22   9  0.282  0.346  0.469  0.815  0.347   68.2
# 6     18  83   76  53  92  22   7  0.278  0.344  0.456  0.801  0.342   68.2
# ...   ..  ..  ...  ..  ..  ..  ..    ...    ...    ...    ...    ...    ...
# 2853  18  73   68  50  94   4   2  0.256  0.322  0.424  0.746  0.319  222.2
# 2854  20  69   74  52  82   4   1  0.268  0.339  0.462  0.801  0.340  222.2
# 2855  16  60   61  43  80   3   2  0.255  0.322  0.425  0.747  0.320  222.2
# 2852  23  75   72  54  92   4   1  0.260  0.331  0.449  0.780  0.333  222.2
# 2856  14  59   50  39  74   3   1  0.257  0.322  0.423  0.745  0.318  222.2
# 0      2  22   18  16  26  11   4  0.269  0.326  0.360  0.687  0.301  643.2
# 2857   3  25   20  16  25   8   3  0.275  0.334  0.382  0.716  0.312  643.2
# 2859   0   5    4   3   6   3   1  0.270  0.322  0.361  0.683  0.299  643.2
# 2860   2  21   23  28  28   9   2  0.257  0.332  0.331  0.663  0.296  643.2
# 2861   1  12   11   8  13   5   3  0.282  0.335  0.386  0.721  0.313  643.2
# 2858   1   6    4   4   6   2   1  0.270  0.325  0.366  0.691  0.302  643.2
# 2862   4  64   44  38  76  38  14  0.258  0.309  0.336  0.646  0.284  643.2
#
#       playerid
# 0         5677
# 0         5677
# 2         5677
# 3         5677
# 1         5677
# 4         5677
# 0         9256
# 5         9256
# 7         9256
# 8         9256
# 9         9256
# 6         9256
# ...        ...
# 2853      2616
# 2854      2616
# 2855      2616
# 2852      2616
# 2856      2616
# 0        15343
# 2857     15343
# 2859     15343
# 2860     15343
# 2861     15343
# 2858     15343
# 2862     15343
#
# [2992 rows x 23 columns]

# %% [markdown]
# ### Once the 2018 MLB season has completed, this workbook will be updated to include actual player stats from the season, along with additional computations and visualizations of how accurate each projection model was

# %% [markdown]
# ##### Notes to self-
# ##### Compare each projection to the player's actual stat line, see which projections tended to be most accurate
# ##### Consider reducing the scope of players to those that were going to play a full season- Results could be skewed from someone like Byron Buxton who people reasonably expected to play a full season but ended up not having much time in the MLB. Limit comparisons to players that played at least 100(?) games this season and reasonably were expected to play that many?
# ##### Average how far each projection model was off for all players- i.e. if Buxton's ZiPS projected 5 steals and he actually had 10, and Brian Dozier's ZiPS projected 3 steals and he actually had 7, overall ZiPS projection was off by 7 steals- Think more if this would be worthwhile to look at league-wide, or for players with 100+ games played
# ##### Consider repeating this project for 2017, 2016, 2015, etc data to get an idea of historical accuracy for each predictive model
